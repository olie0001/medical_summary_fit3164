# %% [markdown]
# # Viewing Dataset File
#
# ---
#
# ## Intentions
#
# - to be able to extract a predetermined subset of the overall dataset
# allowing a brief overview and analysis.
# - After extracting we now want to analyse using Spacy or Hugging Face Transformations (HFT).

# %%
# imports
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# read all the csv files and store them respectively

# create function to limit rows read
def read_first_n_rows(data, n):
    df = pd.read_csv(data, nrows=n)
    return df

rows = 1000
discharge_detail_data = read_first_n_rows("discharge_detail.csv", rows)

# %%
discharge_detail_data.head()
# Out:
#           note_id  subject_id field_name field_value  field_ordinal
# 0  10000032-DS-21    10000032     author         ___              1
# 1  10000032-DS-22    10000032     author         ___              1
# 2  10000032-DS-23    10000032     author         ___              1
# 3  10000032-DS-24    10000032     author         ___              1
# 4  10000084-DS-17    10000084     author         ___              1

# %%
# read in discharge.csv 
discharge_data = read_first_n_rows("discharge.csv", rows)

# %%
discharge_data.head()
# Out:
#           note_id  subject_id   hadm_id note_type  note_seq  \
# 0  10000032-DS-21    10000032  22595853        DS        21
# 1  10000032-DS-22    10000032  22841357        DS        22
# 2  10000032-DS-23    10000032  29079034        DS        23
# 3  10000032-DS-24    10000032  25742920        DS        24
# 4  10000084-DS-17    10000084  23052089        DS        17
#
#              charttime            storetime  \
# 0  2180-05-07 00:00:00  2180-05-09 15:26:00
# 1  2180-06-27 00:00:00  2180-07-01 10:15:00
# 2  2180-07-25 00:00:00  2180-07-25 21:42:00
# 3  2180-08-07 00:00:00  2180-08-10 05:43:00
# 4  2160-11-25 00:00:00  2160-11-25 15:09:00
#
#                                                 text
# 0   \nName:  ___                     Unit No:   _...
# 1   \nName:  ___                     Unit No:   _...
# 2   \nName:  ___                     Unit No:   _...
# 3   \nName:  ___                     Unit No:   _...
# 4   \nName:  ___                    Unit No:   __...

# %%
# retrieve the column names
discharge_data_column_names = []
for column in discharge_data.columns:
    discharge_data_column_names.append(column)
discharge_data_column_names
# Out:
# ['note_id',
#  'subject_id',
#  'hadm_id',
#  'note_type',
#  'note_seq',
#  'charttime',
#  'storetime',
#  'text']

# %%
radiology_detail_data = read_first_n_rows("radiology_detail.csv", rows)
radiology_detail_data.head()
# Out:
#           note_id  subject_id field_name       field_value  field_ordinal
# 0  10000032-RR-14    10000032  exam_code               C11              1
# 1  10000032-RR-14    10000032  exam_name  CHEST (PA & LAT)              1
# 2  10000032-RR-15    10000032  exam_code              U314              1
# 3  10000032-RR-15    10000032  exam_code              U644              3
# 4  10000032-RR-15    10000032  exam_code               W82              2

# %%
radiology_data = read_first_n_rows("radiology.csv", rows)
radiology_data.head()
# Out:
#           note_id  subject_id     hadm_id note_type  note_seq  \
# 0  10000032-RR-14    10000032  22595853.0        RR        14
# 1  10000032-RR-15    10000032  22595853.0        RR        15
# 2  10000032-RR-16    10000032  22595853.0        RR        16
# 3  10000032-RR-18    10000032         NaN        RR        18
# 4  10000032-RR-20    10000032         NaN        RR        20
#
#              charttime            storetime  \
# 0  2180-05-06 21:19:00  2180-05-06 23:32:00
# 1  2180-05-06 23:00:00  2180-05-06 23:26:00
# 2  2180-05-07 09:55:00  2180-05-07 11:15:00
# 3  2180-06-03 12:46:00  2180-06-03 14:01:00
# 4  2180-07-08 13:18:00  2180-07-08 14:15:00
#
#                                                 text
# 0  EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATION...
# 1  EXAMINATION:  LIVER OR GALLBLADDER US (SINGLE ...
# 2  INDICATION:  ___ HCV cirrhosis c/b ascites, hi...
# 3  EXAMINATION:  Ultrasound-guided paracentesis.\...
# 4  EXAMINATION:  Paracentesis\n\nINDICATION:  ___...

# %% [markdown]
# # Next Step - HFT Text Summarisation
#
# ---
#
# The next step in the process is to be able to evaluate if the HFT library will be able to summarise the text
# to a desired level.
#
# ## Install the HFT Library
#
# ### Installing Transformers and Importing Dependencies

# %%
# %pip install transformers
# %pip install tensorflow
# Out:
# Requirement already satisfied: transformers in /Users/alex/anaconda3/lib/python3.11/site-packages (4.32.1)
# Requirement already satisfied: filelock in /Users/alex/anaconda3/lib/python3.11/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in /Users/alex/anaconda3/lib/python3.11/site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/alex/anaconda3/lib/python3.11/site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in /Users/alex/anaconda3/lib/python3.11/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from transformers) (0.3.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/alex/anaconda3/lib/python3.11/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /Users/alex/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/alex/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests->transformers) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow in /Users/alex/anaconda3/lib/python3.11/site-packages (2.15.0)
# Requirement already satisfied: tensorflow-macos==2.15.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (24.3.6)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (4.25.3)
# Requirement already satisfied: setuptools in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (69.1.1)
# Requirement already satisfied: six>=1.12.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (4.10.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.62.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.15.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/alex/anaconda3/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/alex/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Load Summarisation Pipeline

# %%
from transformers import pipeline

summarizer = pipeline("summarization")
# Out:
# /Users/alex/anaconda3/lib/python3.11/site-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %% [markdown]
# ### Summarise Text

# %%
text = """
‘Have some shame’: Boxing world reacts to Mike Tyson news
Boxing has been stunned by the announcement Mike Tyson will fight one of the biggest names in the sport and not everyone is happy.

2 min read
March 8, 2024 - 6:51AM
4 comments
Boxing: Jake Paul took down Ryan Bourland with a first round TKO in their bout in... more
Up Next
Spying probe finds comms equipment on Chinese cranes at…
Cancel
More From Boxing
Former heavyweight champ’s major call on Aussie young gun
Former heavyweight champ’s major call on Aussie young gun
Meet the undefeated Aussie who could be our next UFC champion
Meet the undefeated Aussie who could be our next UFC champion
‘I will take it straight away’: Hall chases Gallen, SBW, rematches
‘I will take it straight away’: Hall chases Gallen, SBW, rematches
Former heavyweight champion Mike Tyson will return to the ring to face Youtuber-turned-boxer Jake Paul in an exhibition bout screened on Netflix, organisers announced on Friday (AEDT).

Tyson, 57, and Paul will face off at the AT&T Stadium in Arlington, Texas, the home of the NFL’s Dallas Cowboys, on July 21, Netflix and Most Valuable Promotions (MVP) announced.

Early reports claimed the fight would be free to Netflix subscribers.

“Given the names involved, that it’s not on PPV and is on Netflix, which is everywhere globally it may be the most watched boxing event ever,” tweeted boxing reporter Dan Rafael.

Mike Tyson and Jake Paul square off. Picture: Netflix
Mike Tyson and Jake Paul square off. Picture: Netflix
Tyson said in a statement he was looking forward to fighting an opponent who is 30 years his junior, insisting that he had been impressed by Paul’s performances in his fledgling boxing career.

“He’s grown significantly as a boxer over the years, so it will be a lot of fun to see what the will and ambition of a ‘kid’ can do with the experience and aptitude of a GOAT,” Tyson said.

Paul fought on the undercard of Tyson’s last outing, an eight-round exhibition against former middleweight king Roy Jones Jr. in Los Angeles in 2020.

Mike Tyson was in top shape when he last fought against Roy Jones Jr in 2020. (Photo by Joe Scarnici / GETTY)
Mike Tyson was in top shape when he last fought against Roy Jones Jr in 2020. (Photo by Joe Scarnici / GETTY)
“I started him on his boxing journey on the undercard of my fight with Roy Jones and now I plan to finish him,” Tyson quipped.

The fight is the latest in what has become a popular trend in recent years, pitting internet celebrities against each other or against recognised boxers, who have already retired or are well past their prime.

Jake Paul’s brother Logan Paul played a key role in pioneering the trend, even fighting against boxing icon Floyd Mayweather in 2021.

Jake Paul was far too good for Ryan Bourland during their cruiserweight fight on March 2. (Photo by Al Bello/Getty Images)
Jake Paul was far too good for Ryan Bourland during their cruiserweight fight on March 2. (Photo by Al Bello/Getty Images)
Jake Paul however has become a bigger draw, building a 9-1 record with six knockouts.

He scored back-to-back knockouts against professional boxers in his last two fights with victories over Ryan Bourland and Andre August.

Tyson, meanwhile, was regarded as one of the most ferocious heavyweight boxers in history.

He reigned as undisputed champion between 1987 and 1990 and won his first belt at the age of 20 years, four months and 22 days to become the youngest heavyweight champion in history.

NEWS.COM.AU00:20
Mike Tyson's insane power at 53-years-old
UP NEXT







Mike Tyson lets the world know that he's still got incredible power at the age of 53.
“He’s the greatest heavyweight of all time…the most vicious KO artist ever,” Paul tweeted after the bout was announced.

“But I’m younger, I’m faster and I’m going to be working my ass off to get stronger. A member of my team sent me this video that Mike’s coach put up two weeks ago and asked me if I’m sure that I want to do this ... yes, yes I do. Heavyweight.”

“My sights are set on becoming a world champion, and now I have a chance to prove myself against the greatest heavyweight champion of the world, the baddest man on the planet and the most dangerous boxer of all time. Time to put Iron Mike to sleep,” Paul added.

But it wasn’t long before other fighters started criticising the match-up.

More Coverage

Horner accuser suspended by Red Bull

Boxing upset throws Tszyu plan into disarray
“You’re fighting someone who was born in 1966,” tweeted Dillon Danis, who fought and lost to Logan Paul. “Have some shame.”

“You should be ashamed of yourself,” UFC great Michael Bisping tweeted to Paul. “And the biggest joke is you don’t even slightly realise why.”
"""

# %%
summarizer(text, min_length=120, do_sample=False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 summarizer(text, min_length=120, do_sample=False)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/pipelines/text2text_generation.py:265, in SummarizationPipeline.__call__(self, *args, **kwargs)
#     241 def __call__(self, *args, **kwargs):
#     242     r"""
#     243     Summarize the text(s) given as inputs.
#     244
#    (...)
#     263           ids of the summary.
#     264     """
# --> 265     return super().__call__(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/pipelines/text2text_generation.py:165, in Text2TextGenerationPipeline.__call__(self, *args, **kwargs)
#     136 def __call__(self, *args, **kwargs):
#     137     r"""
#     138     Generate the output text(s) using text(s) given as inputs.
#     139
#    (...)
#     162           ids of the generated text.
#     163     """
# --> 165     result = super().__call__(*args, **kwargs)
#     166     if (
#     167         isinstance(args[0], list)
#     168         and all(isinstance(el, str) for el in args[0])
#     169         and all(len(res) == 1 for res in result)
#     170     ):
#     171         return [res[0] for res in result]
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/pipelines/base.py:1129, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1121     return next(
#    1122         iter(
#    1123             self.get_iterator(
#    (...)
#    1126         )
#    1127     )
#    1128 else:
# -> 1129     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/pipelines/base.py:1136, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1134 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1135     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1136     model_outputs = self.forward(model_inputs, **forward_params)
#    1137     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1138     return outputs
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/pipelines/base.py:1035, in Pipeline.forward(self, model_inputs, **forward_params)
#    1033     with inference_context():
#    1034         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1035         model_outputs = self._forward(model_inputs, **forward_params)
#    1036         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1037 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/pipelines/text2text_generation.py:187, in Text2TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     185 generate_kwargs["max_length"] = generate_kwargs.get("max_length", self.model.config.max_length)
#     186 self.check_inputs(input_length, generate_kwargs["min_length"], generate_kwargs["max_length"])
# --> 187 output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     188 out_b = output_ids.shape[0]
#     189 if self.framework == "pt":
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/generation/utils.py:1486, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1478         logger.warning(
#    1479             "A decoder-only architecture is being used, but right-padding was detected! For correct "
#    1480             "generation results, please set `padding_side='left'` when initializing the tokenizer."
#    1481         )
#    1483 if self.config.is_encoder_decoder and "encoder_outputs" not in model_kwargs:
#    1484     # if model is encoder decoder encoder_outputs are created
#    1485     # and added to `model_kwargs`
# -> 1486     model_kwargs = self._prepare_encoder_decoder_kwargs_for_generation(
#    1487         inputs_tensor, model_kwargs, model_input_name
#    1488     )
#    1490 # 5. Prepare `input_ids` which will be used for auto-regressive generation
#    1491 if self.config.is_encoder_decoder:
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/generation/utils.py:655, in GenerationMixin._prepare_encoder_decoder_kwargs_for_generation(self, inputs_tensor, model_kwargs, model_input_name)
#     653 encoder_kwargs["return_dict"] = True
#     654 encoder_kwargs[model_input_name] = inputs_tensor
# --> 655 model_kwargs["encoder_outputs"]: ModelOutput = encoder(**encoder_kwargs)
#     657 return model_kwargs
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/bart/modeling_bart.py:820, in BartEncoder.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     817 if inputs_embeds is None:
#     818     inputs_embeds = self.embed_tokens(input_ids) * self.embed_scale
# --> 820 embed_pos = self.embed_positions(input)
#     821 embed_pos = embed_pos.to(inputs_embeds.device)
#     823 hidden_states = inputs_embeds + embed_pos
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/bart/modeling_bart.py:139, in BartLearnedPositionalEmbedding.forward(self, input_ids, past_key_values_length)
#     134 bsz, seq_len = input_ids.shape[:2]
#     135 positions = torch.arange(
#     136     past_key_values_length, past_key_values_length + seq_len, dtype=torch.long, device=self.weight.device
#     137 ).expand(bsz, -1)
# --> 139 return super().forward(positions + self.offset)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/sparse.py:163, in Embedding.forward(self, input)
#     162 def forward(self, input: Tensor) -> Tensor:
# --> 163     return F.embedding(
#     164         input, self.weight, self.padding_idx, self.max_norm,
#     165         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/functional.py:2237, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2231     # Note [embedding_renorm set_grad_enabled]
#    2232     # XXX: equivalent to
#    2233     # with torch.no_grad():
#    2234     #   torch.embedding_renorm_
#    2235     # remove once script supports set_grad_enabled
#    2236     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2237 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# IndexError: index out of range in self

# %% [markdown]
# # Summarising Patient Medical History ID - 10000032
#
# ---
#
# Using the BART model we will summarise the medical history of patient 10000032
#
# Steps:
# - collect all the medical notes for this specific patient
# - parse this information into the HFT model
# - Analyse the output.

# %%
subject_info = []
patient_id = 10000032

# collect the text from patient 10000032
df = radiology_data
df = radiology_data.iloc[:,[1, 7]]
df
# Out:
#      subject_id                                               text
# 0      10000032  EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATION...
# 1      10000032  EXAMINATION:  LIVER OR GALLBLADDER US (SINGLE ...
# 2      10000032  INDICATION:  ___ HCV cirrhosis c/b ascites, hi...
# 3      10000032  EXAMINATION:  Ultrasound-guided paracentesis.\...
# 4      10000032  EXAMINATION:  Paracentesis\n\nINDICATION:  ___...
# ..          ...                                                ...
# 995    10003299  EXAM:  MRI brain.  MRA head.  MRA neck.\n\nCLI...
# 996    10003299  INDICATION:  Evaluation of patient who stepped...
# 997    10003299  INDICATION:  Bilateral hard tissue per requisi...
# 998    10003299  HISTORY:  Screening.\n\nDIGITAL SCREENING MAMM...
# 999    10003299  EXAM:  MRI of the brain.\n\nCLINICAL INFORMATI...
#
# [1000 rows x 2 columns]

# %%
df
# Out:
#      subject_id                                               text
# 0      10000032  EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATION...
# 1      10000032  EXAMINATION:  LIVER OR GALLBLADDER US (SINGLE ...
# 2      10000032  INDICATION:  ___ HCV cirrhosis c/b ascites, hi...
# 3      10000032  EXAMINATION:  Ultrasound-guided paracentesis.\...
# 4      10000032  EXAMINATION:  Paracentesis\n\nINDICATION:  ___...
# ..          ...                                                ...
# 995    10003299  EXAM:  MRI brain.  MRA head.  MRA neck.\n\nCLI...
# 996    10003299  INDICATION:  Evaluation of patient who stepped...
# 997    10003299  INDICATION:  Bilateral hard tissue per requisi...
# 998    10003299  HISTORY:  Screening.\n\nDIGITAL SCREENING MAMM...
# 999    10003299  EXAM:  MRI of the brain.\n\nCLINICAL INFORMATI...
#
# [1000 rows x 2 columns]

# %%
n = len(df)
patient_list = dict()

for _, row in df.iterrows():
    patient_list[row["subject_id"]] = "" 

for index, row in df.iterrows():
    patient_list[row["subject_id"]] += row["text"] + "\n"

patient_list
# Out:
# {10000032: "EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATION:  ___ with new onset ascites  // eval for infection\n\nTECHNIQUE:  Chest PA and lateral\n\nCOMPARISON:  None.\n\nFINDINGS: \n\nThere is no focal consolidation, pleural effusion or pneumothorax.  Bilateral\nnodular opacities that most likely represent nipple shadows. The\ncardiomediastinal silhouette is normal.  Clips project over the left lung,\npotentially within the breast. The imaged upper abdomen is unremarkable.\nChronic deformity of the posterior left sixth and seventh ribs are noted.\n\nIMPRESSION: \n\nNo acute cardiopulmonary process.\n\nEXAMINATION:  LIVER OR GALLBLADDER US (SINGLE ORGAN)\n\nINDICATION:  ___ year-old female with cirrhosis, jaundice.\n\nTECHNIQUE:  Grey scale and color Doppler ultrasound images of the abdomen were\nobtained.\n\nCOMPARISON:  None.\n\nFINDINGS: \n\nLIVER: The liver is coarsened and nodular in echotexture. There is no focal\nliver mass. Main portal vein and its major branches are patent with normal\nhepatopetal flow.  The main hepatic artery shows normal arterial waveform. \nThere is a small amount of ascites.\n\nBILE DUCTS: There is no intrahepatic biliary dilation. The CBD measures 4 mm.\n\nGALLBLADDER: The gallbladder is contracted with a shadowing gallstone.\n\nPANCREAS: Imaged portion of the pancreas appears within normal limits, without\nmasses or pancreatic ductal dilation, with portions of the pancreatic tail\nobscured by overlying bowel gas.\n\nSPLEEN: Normal echogenicity, measuring 13.5 cm.\n\nKIDNEYS: The right kidney measures 12.1 cm. The left kidney measures 13.4 cm.\nNormal cortical echogenicity and corticomedullary differentiation is seen\nbilaterally.\nRETROPERITONEUM: Visualized portions of aorta and IVC are within normal\nlimits.\n\nIMPRESSION: \n\n1. Nodular appearance of the liver compatible with cirrhosis. Signs of portal\nhypertension including small amount of ascites and splenomegaly.\n2.  Cholelithiasis.\n3.  Patent portal veins with normal hepatopetal flow.\n\nINDICATION:  ___ HCV cirrhosis c/b ascites, hiv on ART, h/o IVDU, COPD,\nbioplar, PTSD, presented from OSH ED with worsening abd distension over past\nweek.  // SBP\n\nTECHNIQUE:  Ultrasound guided diagnostic and therapeutic paracentesis\n\nCOMPARISON:  Abdominal ultrasound ___\n\nFINDINGS: \n\nLimited grayscale ultrasound imaging of the abdomen demonstrated\nmoderateascites. A suitable target in the deepest pocket in the right lower\nquadrant was selected for paracentesis.\n\nPROCEDURE:  The procedure, risks, benefits and alternatives were discussed\nwith the patient and written informed consent was obtained.\n\nA preprocedure time-out was performed discussing the planned procedure,\nconfirming the patient's identity with 3 identifiers, and reviewing a\nchecklist per ___ protocol.\n\nUnder ultrasound guidance, an entrance site was selected and the skin was\nprepped and draped in the usual sterile fashion. 1% lidocaine was instilled\nfor local anesthesia.\n\nA 5 ___ catheter was advanced into the largest fluid pocket in the right\nlower quadrant and 1.5 L of serosanguinous fluid was removed.\n\nThe patient tolerated the procedure well without immediate complication.\nEstimated blood loss was minimal.  A sample of the fluid was sent to the lab\nas requested.\n\nDr. ___ attending radiologist, was present throughout the critical\nportions of the procedure.\n\nIMPRESSION: \n\nSuccessful uncomplicated ultrasound guided diagnostic and therapeutic\nparacentesis yielding 1.5 L of serosanguineous fluid from the right lower\nquadrant.  Sample was sent to the lab as requested.\n\nEXAMINATION:  Ultrasound-guided paracentesis.\n\nINDICATION:  ___ year old woman with cirrhosis, ascites despite diuretics  //\nPlease do LVP with albumin post per protocol\n\nTECHNIQUE:  Ultrasound guided therapeutic paracentesis\n\nCOMPARISON:  ___.\n\nFINDINGS: \n\nLimited grayscale ultrasound imaging of the abdomen demonstrated\nmoderateascites. A suitable target in the deepest poc ...
#  10000084: "EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATION:  History: ___ with weakness// ?PNA\n\nTECHNIQUE:  Chest PA and lateral\n\nCOMPARISON:  None.\n\nFINDINGS: \n\nHeart size is mildly enlarged.  The mediastinal and hilar contours are\nunremarkable.  The pulmonary vasculature is normal. Lungs are hyperinflated\nwithout focal consolidation.  Streaky atelectasis is noted in the lung bases. \nNo pleural effusion or pneumothorax is seen. There are no acute osseous\nabnormalities.  Moderate to severe compression deformity of a low thoracic\nvertebral body is of indeterminate age.\n\nIMPRESSION: \n\nMild atelectasis in the lung bases without focal consolidation. \nAge-indeterminate moderate to severe compression deformity of a low thoracic\nvertebral body.\n\nEXAMINATION:  CT HEAD W/O CONTRAST Q111 CT HEAD\n\nINDICATION:  History: ___ with confusion, incontinence, ataxia//\n?hydrocephalus, bleed\n\nTECHNIQUE:  Contiguous axial images of the brain were obtained without\ncontrast. Coronal and sagittal reformations as well as bone algorithm\nreconstructions were provided and reviewed.\n\nDOSE:  Acquisition sequence:\n   1) Sequenced Acquisition 16.0 s, 16.0 cm; CTDIvol = 23.4 mGy (Body) DLP =\n375.0 mGy-cm.\n Total DLP (Body) = 375 mGy-cm.\n\nCOMPARISON:  None.\n\nFINDINGS: \n\nThere is no evidence of infarction, hemorrhage, edema, or mass.  There is\nprominence of the ventricles and sulci suggestive of involutional changes.\n\nThere is no evidence of fracture.  The visualized portion of the remaining\nparanasal sinuses and middle ear cavities are clear.  The visualized portion\nof the orbits are unremarkable apart from bilateral lens replacements.\n\nIMPRESSION:\n\n\n1. No acute intracranial abnormality.  No hydrocephalus.\n\nEXAMINATION:  CHEST (PORTABLE AP)\n\nINDICATION:   ___ with parkinsons, altered, hallucinations// pneumonia\n\nCOMPARISON:  Prior study from ___\n\nFINDINGS: \n\nAP portable upright view of the chest.  Patient's chin obscures the superior\nmediastinum and portions of the lung apices.  The lungs are clear bilaterally\nwithout consolidation to suggest pneumonia.  No large effusion or\npneumothorax.  Cardiomediastinal silhouette appears unchanged.  Imaged bony\nstructures are intact.\n\nIMPRESSION: \n\nLimited, negative.\n\nEXAMINATION:  CT HEAD W/O CONTRAST Q111 CT HEAD\n\nINDICATION:  History: ___ with parkinsons, hallucinations, weakness//\nhemorrhage s/p fall\n\nTECHNIQUE:  Contiguous axial images of the brain were obtained without\ncontrast. Coronal and sagittal reformations as well as bone algorithm\nreconstructions were provided and reviewed.\n\nDOSE:  Acquisition sequence:\n   1) Sequenced Acquisition 16.0 s, 16.0 cm; CTDIvol = 50.2 mGy (Head) DLP =\n802.7 mGy-cm.\n Total DLP (Head) = 803 mGy-cm.\n\nCOMPARISON:  Head CT dated ___.\n\nFINDINGS: \n\nThere is no evidence of infarction,hemorrhage,edema,or mass.  There is\nprominence of the ventricles and sulci suggestive of involutional changes.\n\nThere is no evidence of fracture.  The visualized portion of the paranasal\nsinuses, mastoid air cells, and middle ear cavities are clear.  The visualized\nportion of the orbits are unremarkable, with the exception of changes from\nbilateral lens surgery.\n\nIMPRESSION: \n\nMild atrophy.\nOtherwise normal study.\n\n",
#  10000102: 'CHEST PA AND LATERAL.\n\nCOMPARISON:  None.\n\nHISTORY:  Cough.\n\nFINDINGS:  Cardiomediastinal and hilar contours are within normal limits.\nLungs are clear. There is no focal consolidation, effusion, or pneumothorax.\nThe osseous structures are grossly unremarkable.\n\nIMPRESSION:  No acute cardiopulmonary process.\n\n',
#  10000108: 'HISTORY:  ___ male with left buccal abscess and necrotic molar.  \n\nCOMPARISON:  None available. \n\nTECHNIQUE:  CT of the neck was performed after administration of intravenous\ncontrast.  Multiplanar reformatted images were reviewed.  \n\nFINDINGS: There is left premaxillary superficial soft tissue swelling and\nfluid with enhancement; this represents a phlegmon/cellulitis.  This process\nextends to the level of the left maxillary molars, which demonstrate\nperiapical lucencies, suggestive of an odontogenic origin.  A mandibular\ndental cavity is seen.  The orbits appear normal without CT evidence for\norbital cellulitis.  No lymphadenopathy is detected.  The salivary glands are\nunremarkable.  The thyroid gland is homogeneous in attenuation.  Visualized\ncentral arterial and venous vasculature appears patent and normal in caliber. \nThe orbits are unremarkable.  Although the study is not tailored for\nevaluation of intracranial structures, no acute abnormalities are detected in\nthe visualized portions of the brain.  The visualized lung fields are clear. \nThere is complete opacification of the right maxillary sinus with expansion of\nthe left maxillary ostium.  Mucosal thickening is seen in the left maxillary\nsinus.  The right greater than left ethmoid air cells are partially opacified\nwith air fluid levels.  The mastoid air cells appear well aerated.  \n\nIMPRESSION:\n\n1. Left facial soft tissue edema with phlegmon, likely of odontogenic\ninfectious origin, with periapical lucenies and dental caries. \n\n2. Paranasal sinus disease predominantly involving the right maxillary sinus\nand ethmoid air cells with air fluid levels suggestive of an acute component. \n\n\nFindings discussed with Dr. ___ in person by Dr. ___ at 9:50 p.m. on\n___ at time of initial review. \n\n',
#  10000117: "BILATERAL DIGITAL SCREENING MAMMOGRAM WITH CAD\n\nHISTORY:  Baseline screening.\n\nBILATERAL SCREENING MAMMOGRAM WITH ICAD COMPUTER AIDED DETECTION SOFTWARE\nVERSION 7.2:  There are scattered fibroglandular densities.  There are no\ndominant or spiculated masses, suspicious microcalcifications or areas of\narchitectural distortion. There are no prior studies for comparison. If\noutside studies are made available an addendum will be issued.\n\nIMPRESSION:  No evidence of malignancy.  BI-RADS 1-negative.  Routine\nscreening mammogram in one year is recommended.\n\nINDICATION:  ___ female with right epigastric pain radiating to back,\nrule out gallstones.\n\nCOMPARISON:  No previous exam for comparison.\n\nFINDINGS:  The hepatic architecture is unremarkable in appearance.  A small\nround hyperechoic lesion is seen in segment VI of the liver measuring 1.4 x\n1.4 x 1.8 cm.  This lesion is avascular on color Doppler imaging and the\nappearance clear represents a hemangioma.  A small similar appearing lesion is\nseen peripherally in the right lobe of the liver measuring 0.8 x 0.5 x 0.9 cm\nand also likely representing a small hemangioma.\n\nNo biliary dilatation is seen and the common duct measures 0.3 cm.  The portal\nvein is patent with hepatopetal flow.  There are no gallstones.  The\ngallbladder is normal in appearance.  The pancreas and spleen are unremarkable\nand the spleen measures 9.7 cm.  No hydronephrosis is seen.  The right kidney\nmeasures 10.0 cm and the left kidney measures 9.9 cm.  The aorta is of normal\ncaliber throughout.  The visualized portion of the IVC is unremarkable.\n\nIMPRESSION:\n1.  No gallstones and no signs of cholecystitis.\n2.  Two small hepatic hemangiomas.\n\nCLINICAL HISTORY:  Right upper quadrant pain, evaluate for gallstones.\n\nABDOMINAL ULTRASOUND:\n\nComparison scan from ___ shows the presence of two hemangiomas in the liver.\n\nThe gallbladder shows no evidence of stones.  The gallbladder wall is not\nthickened.  The common duct is not dilated.  The liver is not enlarged.  Two\nhemangiomas are again seen, unchanged since the prior scan.  Normal hepatic\nportal and venous blood flow was present.\n\nPancreas is normal.  The aorta and IVC are unremarkable.  Both right and left\nkidneys are normal.  The spleen is not enlarged.\n\nIMPRESSION:  Normal gallbladder.  No gallstones.  Hepatic hemangiomas is\nunchanged.\n\nEXAMINATION:   CHEST (PA AND LAT)\n\nINDICATION:  History: ___ with PMH GERD presenting with sensation of foreign\nbody in her throat, SOB.  // Foreign body or soft tissue mass in throat?\n\nTECHNIQUE:  Chest PA and lateral\n\nCOMPARISON:  Chest radiograph from ___.\n\nFINDINGS: \n\nLungs remain hyperinflated, without focal consolidation, pleural effusion, or\npneumothorax.  On lateral view, the prominent esophagus is identified between\nthe posterior heart and anterior aortic arch.  The cardiomediastinal\nsilhouette is unremarkable.  The trachea is not deviated.\n\nIMPRESSION: \n\nProminent esophagus on lateral view, without air-fluid level.  Given the\npatient's history and radiographic appearance, barium swallow is indicated\neither now or electively.\n\nEXAMINATION:   NECK SOFT TISSUES\n\nINDICATION:  ___ woman with dysphasia.  Evaluate for soft tissue mass.\n\nTECHNIQUE:  Frontal and lateral radiograph of the neck.\n\nCOMPARISON:  None available.\n\nFINDINGS: \n\nThere is no evidence of prevertebral soft tissue swelling or soft tissue mass,\nwithin the limitations of plain radiography.  C1 through T2 are imaged.  Mild\ndegenerative changes of the cervical spine are most pronounced at C5-C6 and\nC6-C7, were there is disc space narrowing and small osteophyte formation.  No\nevidence of cervical spinal fracture.  Lung apices are grossly clear.\n\nIMPRESSION: \n\nWithin the limitation of plain radiography, no evidence of prevertebral soft\ntissue swelling or soft tissue mass in the neck.\n\nEXAMINATION:  LIVER OR GALLBLADDER US (SINGLE ORGAN)\n\nINDICATION:  ___ with pain ...
#  10000248: 'EXAMINATION:  CT OF THE ABDOMEN AND PELVIS\n\nINDICATION:  Expanding right flank hematoma. History of factor VIII\ndeficiency.\n\nCOMPARISON:  None.\n\nTECHNIQUE:  Multidetector CT images of the abdomen and pelvis were obtained\nwith intravenous contrast. Sagittal and coronal reformations were also\nperformed.\n\nDOSE:  463.1 mGy-cm.\n\n\n\nFINDINGS: \n\nThere is a small right-sided pleural effusion with minimal associated\ncompressive atelectasis.  There is a moderate pectus excavatum deformity.\n\nThe gallbladder, liver, pancreas, spleen, and adrenal glands appear within\nnormal limits. The left kidney is duplex with entirely separate ureters up to\nthe bladder.\n\nThe stomach, small and large bowel appear within normal limits.\n\nThe prostate, seminal vesicles, distal ureters and bladder appear within\nnormal limits. The major arteries and veins appear patent. There is no\nlymphadenopathy or ascites.\n\nFat stranding is present in subcutaneous tissues along the right flank.  The\nright posterior chest wall musculature is expansile and hyperattenuating\nsuggesting hemorrhage with maximal axial ___ of about 6 x 2 cm in axial\n___ but the area of greatest hemorrhage is not necessarily imaged and\nmay lie superior. No active extravasation is identified. There is a hypodense\ncollection layering along the left iliac wing and gluteus medius musculature\nsuggesting sequela of older hematoma including surrounding fat stranding.\n\nNo fracture is identified.  An ossification in paraspinal musculature suggests\nmyositis ossificans from older injury.  There are no suspicious bone lesions.\n\nIMPRESSION: \n\nAcute hemorrhage along the right posterior flank musculature associated with\nright posterior chest wall musculature; the entirety of the hematoma is\nprobably not imaged.  No definite active acute arterial extravasation seen.\nProbable old hematoma along the left posterior flank.\n\n',
#  10000285: "EXAMINATION:  CT ABD AND PELVIS WITH CONTRAST\n\nINDICATION:  ___ with severe generalized abd pain, tender mostly in the\nLLQNO_PO contrast// eval for colitis, diverticulitis, appendicitis\n\nTECHNIQUE:  Single phase contrast: MDCT axial images were acquired through the\nabdomen and pelvis following intravenous contrast administration.\nOral contrast was administered.\nCoronal and sagittal reformations were performed and reviewed on PACS.\n\nDOSE:  Acquisition sequence:\n   1) Stationary Acquisition 0.5 s, 1.0 cm; CTDIvol = 1.2 mGy (Body) DLP = 1.2\nmGy-cm.\n   2) Stationary Acquisition 9.5 s, 1.0 cm; CTDIvol = 22.0 mGy (Body) DLP =\n22.0 mGy-cm.\n   3) Spiral Acquisition 15.4 s, 52.9 cm; CTDIvol = 16.1 mGy (Body) DLP =\n828.0 mGy-cm.\n Total DLP (Body) = 865 mGy-cm.\n\nCOMPARISON:  None.\n\nFINDINGS: \n\nLOWER CHEST: Visualized lung fields are within normal limits.  There is no\nevidence of pleural or pericardial effusion.\n\nABDOMEN:\n\nHEPATOBILIARY: The liver demonstrates homogenous attenuation throughout. \nThere is no evidence of focal lesions. There is no evidence of intrahepatic or\nextrahepatic biliary dilatation.  The gallbladder is within normal limits.\n\nPANCREAS: The pancreas has normal attenuation throughout, without evidence of\nfocal lesions or pancreatic ductal dilatation.  There is no peripancreatic\nstranding.\n\nSPLEEN: The spleen shows normal size and attenuation throughout, without\nevidence of focal lesions.\n\nADRENALS: The right and left adrenal glands are normal in size and shape.\n\nURINARY: The kidneys are of normal and symmetric size with normal nephrogram. \nThere is no evidence of focal renal lesions or hydronephrosis.  There is no\nperinephric abnormality.\n\nGASTROINTESTINAL: The stomach is unremarkable.  Small bowel loops demonstrate\nnormal caliber, wall thickness, and enhancement throughout. The colon and\nrectum are within normal limits, aside from minimal diverticulosis of the\ndescending colon (05:51).  The appendix is normal (05:54).  7 mm nodule\nadjacent to the diverticuli is likely a lymph node (5:60, 7:26).\n\nPELVIS: The urinary bladder and distal ureters are unremarkable.  There is no\nfree fluid in the pelvis.\n\nREPRODUCTIVE ORGANS: The prostate and seminal vesicles are grossly\nunremarkable.  Vasectomy clips are noted.\n\nLYMPH NODES: There is no retroperitoneal or mesenteric lymphadenopathy.  There\nis no pelvic or inguinal lymphadenopathy.\n\nVASCULAR: There is no abdominal aortic aneurysm.  Mild atherosclerotic disease\nis noted.\n\nBONES: There is no evidence of worrisome osseous lesions or acute fracture. \nNonaggressive appearing sclerotic focus in the left femoral head and proximal\nfemur, bilateral pubic rami, and left iliac bone are likely bone islands.\n\nSOFT TISSUES: An umbilical hernia and left inguinal hernia containing fat are\nnoted.\n\nIMPRESSION: \n\nNo acute intra-abdominal or intrapelvic abnormalities to explain patient's\nsymptoms.Normal appendix.  No evidence of acute diverticulitis.\n\n",
#  10000473: 'EXAMINATION:\nChest:  Frontal and lateral views\n\nINDICATION:  History: ___ with cough and fever// cough\n\nTECHNIQUE:  Chest:  Frontal and Lateral\n\nCOMPARISON:  None.\n\nFINDINGS: \n\nStreaky right base opacity seen on the frontal view, not substantiated on the\nlateral view, is felt to most likely be due to overlap of vascular structures,\nbut a subtle consolidation is difficult to exclude in the appropriate clinical\nsetting.  No focal consolidation seen elsewhere.  There is no pleural effusion\nor pneumothorax.  Cardiac silhouette is borderline in size.  The aorta is\nsomewhat tortuous.\n\nIMPRESSION: \n\nStreaky right base opacity seen on the frontal view, not substantiated on the\nlateral view, felt to most likely be due to overlap of vascular structures,\nbut a subtle consolidation is difficult to exclude in the appropriate clinical\nsetting. No focal consolidation seen elsewhere.\n\n',
#  10000560: 'INDICATION:  ___ woman with lower abdominal pain, constant _____,\nevaluate for diverticulitis.\n\nCOMPARISON:  None.\n\nTECHNIQUE:  Multiple MDCT axial images were obtained from the lung bases\nthrough the proximal thighs after administration of 130 cc of Optiray\nintravenously.  Enteric contrast was not administered.  Sagittal and coronal\nreformations were derived.\n\nFINDINGS:\n\nCT OF THE ABDOMEN WITH INTRAVENOUS CONTRAST:\n\nIn the visualized thorax, the lung bases are clear.  There is no pulmonary\nnodule, pneumothorax, or pleural effusion.  The visualized heart is normal.\nThere is no pericardial effusion.\n\nIn the abdomen, the liver enhances homogeneously.  There is no intra- or\nextra-hepatic bile duct dilatation.  The spleen, adrenals, gallbladder, and\npancreas appear normal.  The kidneys symmetrically take up and excrete\ncontrast with no hydronephrosis.  There is a large complex oval but slightly\nlobulated 2.7 x 3.1 x 3.2 cm hypodense lesion (2:35, 300B:33), although not\nsimple fluid density.  On several slices, enhancing internal septation is\ndemonstrated ( for examples 2:36, 2:35).  The amorphous appearance of some\nhigh- density material raises the possibility of hemorrhage within this\ncomplex cystic structure although there is no layering.  Other small bilateral\nhypodensities are seen (for example 2:33, 2:29), too small to characterize.\n\nAbdominal loops of bowel appear normal.  There is no abdominal free air, free\nfluid, or pathologic lymphadenopathy.  The abdominal vasculature appears\nnormal with minor aortic atherosclerotic changes.  The major branches of the\nceliac trunk and SMA are widely patient at their origin.\n\nCT PELVIS WITH INTRAVENOUS CONTRAST:\n\nThe bladder and distal ureters are normal.  There is a small 7-mm hyperdense\nfocus in the fundus of the uterus (2:70, 301B:35) that may represent a small\ncalcified fibroid.  The right adnexa (2:70) and left (2:75) are unremarkable\nwith no demonstration of large cysts.  There is no significant free fluid.\nThere is sigmoidal diverticulosis without evidence of diverticulitis.  There\nis no pelvic free air or pathologic lymphadenopathy.\n\nMUSCULOSKELETAL:\n\nThere is no suspicious osteolytic or osteoblastic lesion.\n\nIMPRESSION:\n\n1.  Right complex septated renal cystic lesion, for which the differential\nincludes neoplasm; outpatient MR is recommended.  Hyperdense material within\nthis cyst may represent  hemorrhagic foci.\n\n2.  No evidence for diverticulitis or nephrolithiasis (although exam limited\nby contrast).  \n\n\nMRI OF THE ABDOMEN FROM ___\n\nHISTORY:  Patient with history of severe abdominal pain.  Also complicated\nright renal lesion.\n\nCOMMENT:  Multiplanar T1- and T2-weighted images of the abdomen were acquired\non a 1.5 Tesla magnet including dynamic 3D imaging prior to, during and after\nIV administration of 15 mL of Magnevist.  Multiplanar 2D  and 3D reformations\nand subtraction images were generated on an independent workstation.\nComparison is made with CT scan from ___.\n\nFINDINGS:  There is a lesion in the mid right kidney.  This is within the\nparenchyma of the kidney and comes in close proximity to the collecting\nsystem.  The lesion is heterogeneous on T2-weighted images with predominantly\nincreased signal intensity and some areas of decreased signal intensity.  On\nthe T1-weighted images, there is a small focus centrally which is of increased\nsignal intensity.  On the post-contrast images, there is vague and low level\ninternal enhancement.  The lesion is suspicious for a cystic renal cell\ncarcinoma.\n\nThere is a 5-mm focus in the lower pole of the left kidney, and a 4-mm focus\nin the lower pole of the right kidney.  These probably represent tiny cysts.\nThere is no evidence of hydronephrosis.  The bilateral renal veins are patent.\nThe patient appears to have two renal arteries bilaterally.  There is no bulky\nretroperitoneal adenopathy.\n\nThe left adrenal is minimally thickened and nodular w ...
#  10000594: 'HISTORY:  ___ male status post trauma to the abdomen.  Evaluation for\nbowel contusion or hematoma.\n\nCOMPARISON:  None available in the ___ system.\n\nTECHNIQUE:  ___ MDCT-acquired axial images from the lung bases to the pubic\nsymphysis were displayed with 5-mm slice thickness.  Intravenous contrast was\nadministered.  Coronal and sagittal reformations were prepared.\n\nCT ABDOMEN WITH INTRAVENOUS CONTRAST:  The lung bases are clear.  There is no\nfocal consolidation, contusion, or pleural effusion.  The visualized heart and\npericardium are within normal limits.\n\nThe liver demonstrates homogeneous parenchymal enhancement without suspicious\nfocal lesion.  Scattered too small to characterize hypodensities are\nidentified within the liver and likely represent simple cysts (2:13).  There\nis no liver laceration or evidence of traumatic injury.  The hepatic veins and\nportal venous system are grossly patent.  No intra- or extra-hepatic biliary\nductal dilatation is identified.  The gallbladder, spleen, and pancreas are\nnormal.  The adrenal glands are symmetric without evidence of hemorrhage or\nnodule.  There is symmetric enhancement and excretion of the kidneys without\nfocal lesion, laceration or hydronephrosis.  The abdominal aorta and its\nbranch vessels are non-aneurysmal and grossly patent.  There is no\nintra-abdominal free fluid or free air.  The stomach and small bowel loops are\nnormal in caliber and configuration without evidence of obstruction or\ninflammation.\n\nCT PELVIS WITH INTRAVENOUS CONTRAST:  The rectum and colon are normal in\ncaliber and configuration without evidence of obstruction or inflammation. \nThere is no evidence of trauma to the large bowel, and there is no pelvic free\nfluid.  The prostate and seminal vesicles appear within normal limits.  The\nbladder is decompressed but is otherwise unremarkable.\n\nOSSEOUS STRUCTURES:  No bone destructive lesion or acute fracture identified. \nA probable bone island is visualized within the left femoral head.  The\nmuscles and soft tissues of the anterior abdominal wall appear intact without\nintramuscular hematoma.\n\nIMPRESSION:  No acute traumatic pathology within the abdomen or pelvis. \nNormal appearance of the bowel without evidence of contusion.  No free fluid\nor air.\n\n',
#  10000635: 'EXAMINATION:  KNEE AP WB, LATERAL AND SUNRISE BILATERAL\n\nINDICATION:  ___ year old woman with bilateral knee pain.  // eval bilateral\nknee      eval bilateral knee                                                 \neval left knee\n\nIMPRESSION: \n\nOn the right, there is a total knee arthroplasty, which appears well seated\nwithout evidence of hardware-related complication.  Soft tissue opacification\nadjacent to the medial condyle could relate to previous surgery or possible\ncalcification of the medial collateral ligament.\nOn the left, there is hypertrophic spurring and compartmental narrowing\nprimarily involving the patellofemoral compartment.  Generalized narrowing is\nseen in the medial and lateral compartments.  There is a superior patellar\nspur, but no evidence of joint effusion.\n\n',
#  10000650: 'INDICATION:  ___ man with fever and cough.\n\nCOMPARISONS:  None.\n\nFRONTAL AND LATERAL CHEST RADIOGRAPH: Cardiac and mediastinal contours appear\nunremarkable.  Pulmonary vascularity is within normal limits.  No focal\nconsolidation or pleural effusions identified.\n\nIMPRESSION:  No evidence of acute cardiopulmonary processes.\n\n',
#  10000719: 'EARLY OB LESS THAN 14 WEEKS\n\nHISTORY:  Uncertain LMP, beta HCG 80,000, evaluate dates.\n\nFINDINGS:  LMP unknown.\n\nPRIOR ULTRASOUND:  None.\n\nThere is an intrauterine gestational sac, yolk sac, and embryonic pole. \nCrown-rump length measures 2.9 cm corresponding to gestational age ___ weeks\nfour days.  ___ by ultrasound is ___.  There was a normal embryonic heart\nrate of 176 BPM.\n\nOvaries are normal.  There is no free fluid in pelvis.\n\nIMPRESSION:  Single live intrauterine pregnancy at nine weeks four days by\ncurrent ultrasound with ___ of ___.\n\n',
#  10000764: 'EXAMINATION:  CHEST (PA AND LAT)\n\nINDICATION:  ___ with hypoxia  // ?pna, aspiration.\n\nCOMPARISON:  None\n\nFINDINGS: \n\nPA and lateral views of the chest provided.   The lungs are adequately\naerated.\n\nThere is a focal consolidation at the left lung base adjacent to the lateral\nhemidiaphragm. There is mild vascular engorgement. There is bilateral apical\npleural thickening.\n\nThe cardiomediastinal silhouette is remarkable for aortic arch calcifications.\nThe heart is top normal in size.\n\nIMPRESSION: \n\nFocal consolidation at the left lung base, possibly representing aspiration or\npneumonia.\n\nCentral vascular engorgement.\n\n',
#  10000826: "INDICATION:  New onset of ascites.\n\nNo comparison is available.\n\nTECHNIQUE:  Axial MDCT images of the abdomen and pelvis were obtained after\nadministration of 130 cc of Optiray intravenously.  Sagittal and coronal\nreformatted images were then acquired.\n\nCT OF THE ABDOMEN WITH IV CONTRAST:  Small bilateral pleural effusion is\nnoted.  The remainder of the lung bases clear.  The liver is edematous and\nenlarged measuring 25 cm in a craniocaudad dimension.  The spleen, adrenal\nglands, kidneys, pancreas, gallbladder, stomach, loops of small bowel and\nlarge bowel have normal appearance.  Large degree of ascites is visualized.\n\nCT OF THE PELVIS WITH IV CONTRAST:  The urinary bladder, distal ureters,\nuterus and adnexa, rectum and sigmoid colon have normal appearance.  No\npathologically enlarged pelvic, mesenteric, retroperitoneal or inguinal\nlymphadenopathy is noted.\n\nBONE WINDOWS:  No concerning lytic or sclerotic lesions are identified.\n\nIMPRESSION:\n\n1.  Large volume ascites and enlarged edematous liver.  The findings are\nsuggestive of acute hepatitis. \n2.  Small bilateral pleural effusions.\n\n\nHISTORY:  New-onset ascites, liver failure, evaluate for portal vein\nthrombosis.\n\nCOMPARISON:  CT ___.\n\nFINDINGS:  The liver is diffusely echogenic, compatible with fatty\ninfiltration.  No focal hepatic lesion is identified.  There is layering\nsludge within the gallbladder, with mild gallbladder wall thickening, which is\nnonspecific, and can be seen with liver disease, or fluid overload.  There is\nno intra- or extra-hepatic biliary ductal dilatation with the CBD measuring 4\nmm.  There is a small amount of ascites within the right lower quadrant of the\nabdomen.  The spleen is normal in size measuring 11.4 cm.  There is a patent\nperiumbilical vein.\n\nDoppler evaluation reveals patent portal venous system, with directionally\nappropriate flow.  The hepatic veins are patent.  The main hepatic artery is\npatent, with sharp systolic upstroke and normal diastolic flow. \n\nIMPRESSION:\n1.  Diffusely echogenic liver, suggestive of fatty infiltration.  Other forms\nof liver disease and more advanced liver disease including fibrosis and\ncirrhosis cannot be excluded.\n\n2.  Layering sludge within the gallbladder, with mild gallbladder wall\nthickening, which may relate to underlying liver disease.  \n\n3.  Patent portal venous system.\n\n4.  Moderate ascites.\n\nHISTORY:  Alcoholic hepatitis. \n\nUS GUIDED PARACENTESIS: Limited ultrasound of the abdomen show moderate amount\nof ascites.  A site for paracentesis was marked under ultrasound guidance in\nthe left lower quadrant.  After explanation of the risks and benefits, written\ninformed consent was obtained from the patient.  A timeout was performed to\nconfirm the procedure and the identity using three parameters.  The patient\nwas prepared and draped in the usual sterile manner.  The superficial tissue\nwas infiltrated with 1% lidocaine and 8.5% bicarbonate for local anesthesia. \nA 5 ___ ___ catheter was inserted percutaneously into the peritoneal\ncavity. Samples from the ascitic fluid  were obtained for studies, as\nrequested.  Approximately 2.5 liters of clear ascites was removed. The patient\ntolerated well the procedure with no immediate complications.\n\nThe attending, Dr. ___, was present and supervising throughout.\n\nIMPRESSION:  Successful diagnostic and therapeutic paracentesis yielding 2.5\nliters of ascitic fluid. \n\nINDICATION:  ___ woman with liver disease, now with fever, please\nevaluate for infection.\n\nTECHNIQUE:\nSingle semi-upright portable AP view of the chest was acquired.\n\nFINDINGS:\nLungs are hyperlucent without hyperinflation.  There is a moderate right\npleural effusion. No evidence of pneumonia.  Cardiomediastinal silhouette and\nhila are normal.  No pneumothorax.\n\n\n\nINDICATION:  ___ female with alcoholic hepatitis, ascites; evaluate\nfor patency of portal vein.\n\nCOMPARISON:  Liver ultrasound, ___.\n\nFINDINGS ...
#  10000891: 'EXAMINATION:  BILATERAL DIGITAL SCREENING MAMMOGRAM INTERPRETED WITH CAD\n\nINDICATION:  Screening.\n\nCOMPARISON:  Priors available on PACS.\n\nTECHNIQUE:  Digital CC and MLO views were obtained.  Computer aided detection\nwas utilized and assisted with interpretation.\n\nFINDINGS: \n\nTissue density: B- There are scattered areas of fibroglandular density.\nThere is no dominant mass, unexplained architectural distortion or suspicious\ngrouped microcalcifications.  Skin lesion in the slightly outer slightly upper\nright breast is again noted.  There is no significant change.\n\nIMPRESSION: \n\nNo specific evidence of malignancy.\n\nRECOMMENDATION:  Age and risk appropriate screening.\n\nNOTIFICATION:  A summary letter will be sent to the patient with this result.\n\nBI-RADS:  1 Negative.\n\n\n\nEXAMINATION:  Bilateral LOWER EXT VEINS\n\nINDICATION:  ___ with BILATERAL CALF PAIN, Elevated D-dimer sent for u/s\nplease do bilateral ___.  L calf greater pain.// BILATERAL CALF PAIN, Elevated\nD-dimer sent for u/s please do bilateral ___,\n\nTECHNIQUE:  Grey scale, color, and spectral Doppler evaluation was performed\non the bilateral lower extremity veins.\n\nCOMPARISON:  None.\n\nFINDINGS: \n\nThere is normal compressibility, color flow, and spectral doppler of the\nbilateral common femoral, femoral, and popliteal veins. Normal color flow and\ncompressibility are demonstrated in the posterior tibial and peroneal veins.\n\nThere is normal respiratory variation in the common femoral veins bilaterally.\n\nNo evidence of medial popliteal fossa (___) cyst.\n\nIMPRESSION: \n\nNo evidence of deep venous thrombosis in the right or left lower extremity\nveins.\n\n',
#  10000898: 'EXAMINATION:  ABDOMEN US (COMPLETE STUDY)\n\nINDICATION:  ___ year old woman with nl exam, has known pancreatic cyst  // ___\nyear follow up\n\nTECHNIQUE:  Grey scale and color Doppler ultrasound images of the abdomen were\nobtained.\n\nCOMPARISON:  Abdominal ultrasound dated ___\n\nFINDINGS: \n\nLIVER: The echogenicity of the liver is echogenic. The contour of the liver is\nsmooth. There is no focal liver mass. Main portal vein is patent with\nhepatopetal flow. There is no ascites.\n\nBILE DUCTS: There is no intrahepatic biliary dilation. The CBD measures 4 mm.\n\nGALLBLADDER: The patient is status post cholecystectomy\n\nPANCREAS: A cyst in the tail of the pancreas measuring 6 x 6 x 5 mm without\ninternal vascularity is unchanged from prior.  The remainder of the pancreas\nis unremarkable.\n\nSPLEEN: Normal echogenicity, measuring 8.8 cm.\n\nKIDNEYS: The right kidney measures 10.1 cm. The left kidney measures 10.2 cm.\nNormal cortical echogenicity and corticomedullary differentiation is seen\nbilaterally. There is no evidence of masses, stones or hydronephrosis in the\nkidneys.\n\nRETROPERITONEUM: Visualized portions of aorta and IVC are within normal\nlimits.\n\nIMPRESSION:\n\n\n1. Persistent echogenic liver consistent with steatosis. Other forms of liver\ndisease and more advanced liver disease including steatohepatitis or\nsignificant hepatic fibrosis/cirrhosis cannot be excluded on this study.\n2. Unchanged small subcentimeter cyst or dilated side branch in the tail of\nthe pancreas.  Recommend continued imaging followup in ___ year.\n\nINDICATION:  Screening, positive family history with sister diagnosed at age\n___.\n\nDIGITAL SCREENING MAMMOGRAPHY WITH ICAD, COMPUTER-AIDED DETECTION SOFTWARE: \nBreast parenchyma is heterogeneously dense somewhat limiting sensitivity of\nmammography.  There are no dominant masses, areas of architectural distortion\nor suspicious microcalcifications.  There has been no change from ___.\n\nIMPRESSION:  No evidence of malignancy.  Annual screening mammography is\nrecommended.\n\nBI-RADS 1 - negative.\n\nEXAMINATION:  ___\n\nINDICATION:  ___ year old woman with worsening LBP, pain into both legs // r/o\nworsening spinal stenosis\n\nTECHNIQUE:  Routine ___ nonenhanced MR examination of the lumbar spine, with\nsagittal T2 weighted IDEAL sequence.\n\nCOMPARISON:  MRI of lumbar spine from ___.\n\nFINDINGS: \n\nThere are five non-rib-bearing lumbar-type vertebrae, with normal height.\nAgain seen is grade 1 anterolisthesis of L4 on L5, unchanged since the prior\nexam. The normal lumbar lordosis is maintained.  The vertebral bodies\ndemonstrate overall normal bone marrow signal. There is no pathologic\nparaspinal soft tissue hyperintensity.  The paraspinal soft tissues, including\nthe regional musculature, and the limited included retroperitoneum are grossly\nunremarkable, allowing for the non-enhanced acquisition.\n\nThe included distal spinal cord is normal in signal and terminates at L1.\nThere is a normal distribution of cauda equina nerve roots within the thecal\nsac.\n\nThere is multilevel degenerative disease, as follows:\n\nT12-L1: There is no significant canal or neural foraminal narrowing.\n\nL1-2: There is mild facet arthropathy bilaterally without evidence of canal or\nneural foraminal stenosis.\n\nL2-3: There is a diffuse disc bulge with a central protrusion and bilateral\nfacet arthropathy causing mild canal stenosis. There is no neural foraminal\nstenosis. This is unchanged since the prior exam\n\nL3-4: There is a broad disc bulge with bilateral facet arthropathy causing\nmoderate- severe canal stenosis and mild-moderate left neural foraminal\nstenosis.  , possibly contacting the exiting nerve root on the left. Overall\nthis is slightly worsened since the prior exam.\n\nL4-5: There is uncovering of the disc from spondylolisthesis. Severe facet\narthropathy and a disc bulge causes severe canal stenosis.  With mild-moderate\nright  neural foraminal narrowing. This has sli ...
#  10000904: 'CT OF THE NECK PERFORMED ON ___\n\nCOMPARISON:  None.\n\nCLINICAL HISTORY:  ___ woman with sore throat, marked tonsillar\nswelling, worse despite antibiotics, question peritonsillar abscess.\n\nTECHNIQUE:  Multidetector CT was used to obtain contiguous axial images\nthrough the neck following the administration of IV contrast.  Coronal and\nsagittal reformations were provided.\n\nFINDINGS:  There is enlargement of the adenoid and palatine tonsils though\nthere is no peritonsillar collection.  The parapharyngeal fat is preserved. \nVascular structures are patent.  Parotid glands and submandibular glands are\nnormal.  Thyroid gland is unremarkable.\n\nWithin the imaged right upper lung, 2 confluent areas of airspace\nconsolidation is noted which is compatible with pneumonia.  The imaged left\nupper lung is clear.  There is enlargement of the upper cervical chain lymph\nnodes, likely reactive.  Minimal mucosal thickening in the inferior aspect of\nthe right maxillary sinus noted.  The bony structures appear intact.\n\nIMPRESSION:  \n1.  Right upper lobe pneumonia.\n2.  Enlarged adenoids and palatine tonsils with associated prominent likely\nreactive lymph nodes without sign of peritonsillar collection.\n\n',
#  10000935: "ADDENDUM: There is bilateral sclerosis in the iliac bones consistent with\nsacroiliitis.\n\nCLINICAL HISTORY:  ___ female who presents with a chief complaint of\nleft-sided head pulsation and seeing blue spots.  Evaluate for infarct.\n\nCOMPARISON:  None.\n\nNON-CONTRAST HEAD CT:  No hemorrhage, hydrocephalus, or shift of normally\nmidline structures.  The gray-white matter differentiation is preserved.  No\nmajor vascular territorial infarct is apparent. No osseous abnormality.  The\nparanasal sinuses and mastoid air cells remain normally aerated.\n\nIMPRESSION:  No hemorrhage.\n\nMRI OF THE BRAIN.\n\nCLINICAL INFORMATION:  Patient with question of aneurysm in the suprasellar\nregion.\n\nTECHNIQUE:  T1 sagittal and axial and FLAIR T2 susceptibility and diffusion\naxial images were obtained before gadolinium.  T1 axial and coronal images\nwere obtained following gadolinium.  Correlation was made with the head CT of\n___.\n\nFINDINGS:  The ventricles and extra-axial spaces are normal in size.  There is\nno evidence of midline shift, mass effect or hydrocephalus.  There are no\nfocal signal abnormalities identified.  Following gadolinium, no evidence of\nabnormal parenchymal, vascular or meningeal enhancement identified.  The\nsuprasellar region is normal on the sagittal images.  The craniocervical\njunction also appears normal on the sagittal images.  Incidentally noted is a\nsmall approximately 1.5-cm CSF space at the anterior aspect of the right\ncerebellum with slight indentation indicating a small incidental arachnoid\ncyst.  Incidentally also noted is pneumatization with fluid in the right\npetrous apex air cells.\n\nThere is a slight prominence of the nasopharyngeal soft tissues identified.\nThis is inappropriate for patient's age and clinical correlation recommended.\n\n\n\nIMPRESSION: (1) Small incidental arachnoid cyst right side of posterior fossa.\n(2) Prominence of nasopharyngeal soft-tissues, in appropriate for patient's\nage. Direct inspection recommended.\n\nPA AND LATERAL CHEST, ___\n\nHISTORY:  Status post right lower lobe resection for carcinoid.  Now short of\nbreath.\n\nIMPRESSION:  PA and lateral chest compared to ___:\n\nThere has been no interval radiographic change.  Lung volumes are small and\nthe right hemidiaphragm is moderately elevated.  Pleural thickening joins the\nleft lower costal pleural margin, unchanged.  No focal pulmonary abnormality\nis seen.  There is no left pleural effusion.  The right hemidiaphragm remains\nelevated.  Heart size normal.  Upper mediastinum has normal contours. \nGranulomatous calcifications are seen in hilar nodes.\n\nPeriosteal regrowth does not fully bridge surgical fracture of the right\nposterior sixth rib.\n\nHISTORY:  ___ female with osteoarthritis of bilateral knees, evaluate\nfor progression.\n\nCOMPARISON:  ___ and ___. \n\nLEFT KNEE, THREE VIEWS:  There is no acute fracture or dislocation.  There is\nmoderate joint space narrowing of the medial compartment of the knee, with\nassociated osteophytes.  There is mild lateral translocation of the tibia\nrelative to the femur.  Mild degenerative changes of the lateral and\npatellofemoral compartments are seen, with small spurring.  There is no joint\neffusion.  No soft tissue calcification or radiopaque foreign body identified.\n\nRIGHT KNEE, THREE VIEWS:  There is no acute fracture or dislocation.  There is\nmoderate joint space narrowing within the medial compartment of the knee, with\nassociated spurs.  There is also mild lateral translocation of the tibia\nrelative to the femur.  Mild degenerative changes are also present within the\nlateral and patellofemoral compartments of the knee with small spurs.  There\nis no joint effusion.  No soft tissue calcification or radiopaque foreign body\nidentified.\n\nIMPRESSION:  Moderate osteoarthritis of the medial compartment of the knee\nbilaterally.\n\nHISTORY:  ___ female with history of herniated C5-6 disc, now with\ncontinued neck pain.  Evaluate for DJD o ...
#  10000951: 'INDICATION:  History: ___ with likely inversion injury, pain/swelling mostly\nover lateral malleolus// r/o fx\n\nTECHNIQUE:  Left ankle, three views\n\nCOMPARISON:  None.\n\nFINDINGS: \n\nNo acute fracture or dislocation.  Ankle mortise is symmetric.  Talar dome is\nsmooth.  No worrisome lytic or sclerotic osseous abnormality.  A small\ntibiotalar joint effusion is present.  There are no radiopaque foreign bodies\nor soft tissue calcifications.\n\nIMPRESSION: \n\nNo acute fracture or dislocation.\n\n',
#  10000980: "HISTORY:  Screening.\n\nDIGITAL SCREENING MAMMOGRAPHY INTERPRETED WITH CAD:  Heterogeneously dense\nparenchyma with additional view obtained on each side.  There are two small\nnodules in the upper outer left breast suggesting intramammary lymph nodes and\nunchanged from ___ and little change from ___.  No new mass,\nclustered microcalcifications, or architectural distortion.  Vascular\ncalcifications.\n\nIMPRESSION:  No evidence of malignancy.  BI-RADS 2 -- benign findings.\n\nINDICATION:  Screening. \n\nDIGITAL SCREENING MAMMOGRAM WITH CAD: Heterogeneously dense breast parenchyma.\n___ sub 5 mm nodular densities are seen in the left upper outer breast\nconsistent with intramammary lymph nodes.  No new mass, clustered\nmicrocalcifications, or architectural distortion is seen.  No change since ___ and ___.  Two additional views on the left and one on\nthe right wobtained.  \n\nIMPRESSION:  No evidence of malignancy.  BI-RADS 2 -benign findings.\n\nHISTORY:  ___ female with near syncopal episode.\n\nSTUDY:  PA and lateral chest radiograph.\n\nCOMPARISON:  ___.\n\nFINDINGS:  The heart size is at the upper limits of normal.  The mediastinal\ncontours demonstrate marked tortuosity of the aorta and calcified\natherosclerotic disease of the knob, both of which appear similar compared to\nprior study.  The lungs are clear.  There is no pleural effusion or\npneumothorax.  Exaggerated kyphosis of the thoracic spine is noted.\n\nIMPRESSION:  No acute cardiopulmonary process.\n\nHISTORY:  ___ female with prior CVA, now presenting with TIA symptoms\nincluding leg weakness and slurred speech.\n\nSTUDY:  CT of the head without contrast; coronal and sagittal reformatted\nimages were also generated.\n\nCOMPARISON:  MRI/MRA of the brain and neck from ___.\n\nFINDINGS:  There is no intracranial hemorrhage.  Calcifications are noted in\nthe basal ganglia bilaterally (2A; 9).  Hypodensities in both basal ganglia\nlikely represent old infarcts (2A; 11).  Hypodensities are also noted in both\ncerebellar hemispheres (2A;6), also representing old infarcts, the\naforementioned old infarcts are similar in appearance compared to prior study.\nThe previously described infarct involving the corpus collosum is not well\nvisualized on this exam.  The gray-white differentiation continues to be well\ndelineated.  There is no edema or mass effect.  The ventricles and sulci are\nunremarkable given the patient's age.  Paranasal sinuses and mastoid air cells\nare clear.\n\nIMPRESSION:  Old infarcts as described above; no acute intracranial process;\nplease note MR is more sensitive for the detection of acute CVA.\n\nINDICATION:  Shortness of breath.\n\nCOMPARISONS:  ___.\n\nFINDINGS: PA and lateral views of the chest demonstrate low lung volumes. \nTiny bilateral pleural effusions are new since ___.  No signs of\npneumonia or pulmonary vascular congestion.  Heart is top normal in size\nthough this is stable. Aorta is markedly tortuous, unchanged.  Aortic arch\ncalcifications are seen.  There is no pneumothorax.  No focal consolidation. \nPartially imaged upper abdomen is unremarkable.\n\nIMPRESSION: Tiny pleural effusions, new. Otherwise unremarkable. \n\nHISTORY:  Screening.  \n\nDIGITAL HOLOGIC SCREENING MAMMOGRAM WITHOUT TOMOSYNTHESIS:  Heterogeneously\ndense breast tissue.  Dystrophic calcified fibroadenoma in the upper outer\nleft breast.  Vascular calcifications.  Two small apparently intramammary\nlymph nodes are unchanged from ___, and ___.  No\nnew mass, suspicious microcalcification, or architectural distortion.\n\nIMPRESSION:  No evidence of malignancy.\nBI-RADS 2 - Benign findings.\n\n\nHISTORY:  Right foot pain and tenderness worsening over the last 24 hours. \nTenderness along the ___ metatarsal.  History of diabetic neuropathy and\nperipheral vascular disease.\n\nTECHNIQUE:  Right foot, 3 views.\n\nCOMPARISON:  ___.\n\nFINDINGS:\n\nNo acute fracture or dislocation is identified.  Diffuse mild degenerative\nchanges are seen involving the ...
# ...
#  10003137: 'EXAMINATION:  PELVIS, NON-OBSTETRIC\n\nINDICATION:  ___ year old woman with pelvic pain and history of cysts//\nevaluate for ovarian cyst\n\nTECHNIQUE:  Grayscale ultrasound images of the pelvis were obtained with\ntransabdominal approach followed by transvaginal approach for further\ndelineation of uterine and ovarian anatomy.  3D reformations were performed.\n\nCOMPARISON:  Ultrasound from ___\n\nFINDINGS: \n\nThe uterus is anteverted and measures 7.1 x 3.2 x 6.1 cm. The endometrium is\nhomogenous and measures 4 mm.  An IUD is in appropriate position.\n\nThe ovaries are unremarkable.  The previously seen 5.6 cm right ovarian cyst\nhas resolved.  There is no free fluid.\n\nIMPRESSION: \n\nResolution of prior ovarian cyst.\n\nIUD in appropriate position.\n\nEXAMINATION:  PELVIS, NON-OBSTETRIC\n\nINDICATION:  ___ year old woman with pelvic pain, has IUD  // eval for proper\nplacement of IUD, structural abnormals\n\nTECHNIQUE:  Grayscale ultrasound images of the pelvis were obtained with\ntransabdominal approach followed by transvaginal approach for further\ndelineation of uterine and ovarian anatomy.\n\nCOMPARISON:  Pelvic ultrasound dated ___\n\nFINDINGS: \n\nThe uterus is anteverted and measures 9.1 cm x 3.3 cm x 5.4 cm. The\nendometrium is homogenous and measures 4 mm. The IUD was demonstrated within\nthe endometrial cavity. The IUD appears satisfactorily placed.\n\nThe ovaries are normal. There is no free fluid.\n\nIMPRESSION: \n\nNormal uterus and ovaries.  Satisfactory position of the IUD within the\nendometrial cavity.\n\n',
#  10003199: 'HISTORY:  ___ female status post fall with large effusion, inability\nto flex knee.\n\nCOMPARISON:  None.\n\nFINDINGS:\n\nAP and frogleg views of the right hip.  AP and lateral views of the distal\nright femur.  AP and lateral views of the right knee.  AP and lateral views of\nthe distal right tibia and fibula.\n\nThe bones are diffusely osteopenic. Right total hip arthroplasty is noted.\nThere is no periprosthetic lucency or fracture.  Pubic symphysis is\nunremarkable.\n\nThere is an acute lateral tibial plateau fracture.  There is some inferior\ndisplacement of the fracture fragment inferiorly.  There is also cortical\nirregularity with a horizontally oriented lucency through the patella\ninferiorly suspicious for additional fracture.  Elsewhere, the knee is notable\nfor diffuse tricompartmental degenerative changes and osteopenia. \nLipohemarthrosis is noted.\n\nDistally, the right tibia and fibula are intact.\n\nIMPRESSION:\n\nAcute impacted lateral tibial plateau fracture.  Horizontally oriented\nfracture through the inferior aspect of the patella.  Associated\nlipohemarthrosis.\n\n\nHISTORY:  Fall, will undergo surgery.  Preop chest x-ray.\n\nTECHNIQUE:  Frontal AP and lateral chest radiographs were obtained.\n\nCOMPARISON:  None available.\n\nFINDINGS:  There is no evidence of focal consolidation, pleural effusion,\npneumothorax, or pulmonary edema seen.  Calcified lymph nodes are seen within\nthe left hilar region.  The heart size and mediastinal contours are normal.\n\nIMPRESSION:  No acute cardiopulmonary process.\n\nSTUDY:  Right tib-fib, ___. \n\nCLINICAL HISTORY:  Patient with ORIF of right tibial fracture.\n\nFINDINGS:  There are no prior studies for comparison.\n\nThere is a lateral tibial plateau fracture.  This is fixated by a lateral\nfracture plate and associated screws.  There are no signs for hardware-related\ncomplications.  There are baseline degenerative changes of all three\ncompartments, worse in the patellofemoral compartment.  Large corticated\ndensity superior to the patella is seen.  The total intraservice fluoroscopic\ntime was 39.4 seconds.\n\nHISTORY:  ___ female with right proximal tibia fracture.\n\nCOMPARISON:  Intraoperative films dated ___.\n\nFINDINGS:\n\nRIGHT KNEE, AP AND LATERAL VIEWS:  There is plate and interlocking screws\nabout the lateral proximal tibia, achieving good anatomic alignment.  There is\nno evidence of hardware failure or loosening.  There are severe\ntricompartmental degenerative changes noted with large osteophytes.  No joint\neffusion is present.  Multiple skin staples are seen about the lateral and\nmedial aspect of the proximal tibia.\n\nIMPRESSION:  Status post fixation of lateral proximal tibial fracture without\nevidence of hardware failure or loosening.\n\nRADIOGRAPHS OF THE RIGHT KNEE\n\nHISTORY:  Right proximal tibia fracture follow-up. \n\nCOMPARISONS:  ___.\n\nTECHNIQUE:  Right knee, AP and lateral.\n\nFINDINGS:  The patient is status post open reduction and internal fixation of\nthe proximal tibia with placement of a lateral fixation plate and several\nscrews spanning a tibial plateau fracture involving the lateral side.  There\nis a similar degree of mild irregularity along the lateral tibial plateau but\nwithout any clear step-off over 2 mm.  The medial and lateral compartment\nspaces appear preserved with small to moderate-sized marginal osteophytes, but\npatellofemoral degenerative changes are severe with complete effacement of the\njoint space.  An ossification projects above the patella, a suspected\nintra-articular loose body.  The bones appear demineralized.\n\nIMPRESSION:  Moderate-to-severe patellofemoral degenerative changes.  Healing\nlateral tibial plateau fracture.  Status post ORIF without hardware loosening.\n\nINDICATION:  ___ woman with right knee fracture.\n\nCOMPARISON:  ___.\n\nFINDINGS:  AP and lateral views of the right knee were obtained.  Side plate\nand screws transfix previously noted tibial plateau fracture which is ...
#  10003203: 'Findings were discussed with Dr. ___ the phone by Dr. ___ at\n2:00 p.m. on ___.\n\n\nINDICATION:  Status post mechanical fall with displaced femoral head fracture\nand after attempted reduction.\n\nCOMPARISONS:  Outside hospital right shoulder films from ___.\n\nTECHNIQUE:  Three views of the right shoulder were provided.\n\nFINDINGS:  \n\nThere is a very unusual fracture of the right proximal humeral head, with a\ntransverse fracture line subtending the superior  portion of the greater\ntuberosity and the superior portion of the articular surface of the humeral\nhead.  This superior fracture fragment is displaced anteriorly and inferiorly\nand rotated from its usual position and it appears to lie in the region of the\naxilla. No obvious underlying bone lesion is detected. \n\nThe glenohumeral joint may be narrowed and there is spurring along the\ninfeiror humeral head, but no gross displacement of the remainder of the\nproximal humerus is identified.  \n\nThe AC joint remains congruent, with moderate degenerative chanegs and\nsubacromial spurring.  Probably diffuse osteopenia. Incidental note made of\nadvanced degenerative changes in the cervical spine.\n\nIMPRESSION:  Unusual fracture through the upper portion of the humeral head,\nwith signfiicant displacement superior fragment. No definite underlying bone\nlesion. No obvious surgical neck component.  Clinical correlation requested to\nassess for an appropriate mechanism of injury.\n\n\nINDICATION:  Status post mechanical fall with displaced humeral head fracture.\nChest x-ray for preop evaluation.\n\nCOMPARISONS:  None.\n\nFINDINGS:  Single portable AP chest radiograph is provided.  There is no focal\nconsolidation, pleural effusion or pneumothorax.  Biapical scarring, left\ngreater than right is noted.  Cardiomediastinal silhouette is notable for a\ntortuous aorta but normal in size.  The displaced right humeral head fracture\nis better evaluated on the dedicated shoulder films.\n\nIMPRESSION: No acute cardiopulmonary process.\n\n\nSTUDY:  Right humerus intraoperative study ___.\n\nCLINICAL HISTORY:  Patient with proximal humerus fracture.\n\nFINDINGS:  Several fluoroscopic images of the right shoulder from the\noperating room demonstrate subsequent placement of a fracture plate fixating\nthe displaced fracture of the humeral head.  It is now relocated within the\nglenoid.  Please refer to the operative note for additional details.\n\nHISTORY:  Pain.\n\nFINDINGS:  In comparison with the operative study of ___, there is little\nchange in the appearance of the fixation device about previously described\nfracture of the proximal humerus.  Little if any callus formation is\nappreciated.\n\n',
#  10003255: 'CHEST RADIOGRAPH PERFORMED ON ___.\n\nCOMPARISON:  None.\n\nCLINICAL HISTORY:  ___ man with elevated CPK, chest pain, question\nacute intrathoracic process.\n\nFINDINGS:  PA and lateral views of the chest are obtained.  There is a mild\npectus deformity noted on the lateral view.  The lungs appear well expanded\nwithout focal consolidation, effusion, or pneumothorax.  No definite signs of\nCHF.  The heart size appears slightly prominent, but this could be due to the\naforementioned pectus excavatum deformity.  Imaged osseous structures are\nintact.  Clips in the right upper quadrant noted.\n\nIMPRESSION:  Pectus excavatum deformity likely accounting for top normal heart\nsize.  Otherwise, unremarkable.\n\n',
#  10003299: "ADDENDUM  Please note the following addendum:\n\nCentral, partially occlusive filling defect within the right internal jugular\nvein (for example, 302:13), concerning for thrombus.  Recommend ultrasound for\nfurther evaluation.\n\n The findings were discussed with ___. by ___, M.D. on the\ntelephone on ___ at 3:46 pm, 1 minutes after discovery of the findings.\n\nADDENDUM  Please note the following addition: Two lytic appearing bilateral\nscapular lesions measure up to 1.2 centimeters (5:13, 5:97).  No other\ndefinite worrisome osseous lesions are identified.\n\nINDICATION:  ___ woman with headache last night and right-sided\nnumbness, weakness and slurring in the morning, now resolved.\n\nCOMPARISON:  ___.  \n\nTECHNIQUE:  Contiguous axial images were obtained through the brain.  No\ncontrast was administered.\n\nFINDINGS:  There is no intracranial hemorrhage, edema, shift of normally\nmidline structures or evidence of major vascular territorial infarct.  The\ngray-white differentiation is preserved.  Basilar cisterns are preserved.\nVentricles and sulci are normal in size and configuration.  There is no\nfracture.  Mastoid air cells are normally aerated.\n\nIMPRESSIONS:  No intracranial hemorrhage or other acute abnormality.  However,\nMRI is more sensitive for detection of acute ischemia.\n\nHISTORY:  ___ female with new onset right-sided numbness and weakness,\nprior history of smoking and colon cancer, to rule out intrathoracic\npathology.\n\nTECHNIQUE:  AP and lateral radiographs of the chest were performed. \nComparison is made with CT chest of ___ and chest radiograph of ___.\n\nFINDINGS:\nThere are background changes of COAD with no evidence of an acute\ncardiopulmonary process.\n\nCLINICAL HISTORY:  ___ female with right-sided numbness and weakness.\nEvaluate for infarct.\n\nCOMPARISON:  None.\n\nTECHNIQUE:  Non-contrast multiplanar T1- and T2-weighted images of the brain\nwere obtained.  3D and 2D time-of-flight MR arteriography was performed of the\ncircle of ___ and neck, respectively.\n\nFINDINGS:  An 11-mm focus of restricted diffusion is identified in the left\nparamedian pons, which on corresponding FLAIR and T2 images show bright signal\nconsistent with subacute infarct.  There is no hemorrhage, hydrocephalus, or\nshift of normally midline structures.  The ventricles and sulci are normal in\ncaliber and configuration.  Scattered T2 and FLAIR signal abnormality in the\nperiventricular and subcortical white matter reflect chronic microvascular\nischemic change.  Maxillary sinuses show mild mucosal thickening and the\nmastoid air cells contain small amount of fluid.\n\n3D and 2D time-of-flight MRA of the head and neck show patency of the carotids\nand right vertebral arteries and their major branches without evidence of\nstenosis, occlusion, or aneurysm formation.  The left vertebral artery is not\nwell visualized throughout its course, which may be related to small size,\nhowever occlusion is not exluded and thus further evaluation with CTA is\nrecommended.\n\nIMPRESSION:\n1.  Subacute infarct of the left paramedian pons.\n\n2.  Left vertebral artery is not visualized throughout its entire course,\nwhich may be related to its diminutive nature; however, occlusion is not\nentirely excluded and thus recommend CTA for further evaluation.\n\n\nMR HEAD WITH CONTRAST, ___\n\nHISTORY:  Optic nerve edema on eye examination in a patient with colon cancer.\n\nSagittal and axial short TR, short TE spin echo imaging was performed.  16 cc\nof Magnevist intravenous contrast were administered, and diffusion, gradient\necho, long TR, long TE fast spin echo, FLAIR, and axial short TR, short TE\nspin echo, and sagittal MP-RAGE imaging were performed.  The MP-RAGE images\nwere reformatted into axial and coronal orientations.  Comparison to a head MR\n___.\n\nFINDINGS:  There is no evidence of hemorrhage, edema, masses, or mass effect. \nThere is no evidence of recent infarction.  There is defect in the left pons\ncorr ...

# %% [markdown]
# ## Summarisation using the BioGPT Model
#
# ---
#
# The BioGPT model was proposed in BioGPT: generative pre-trained transformer for biomedical text generation and mining by Renqian Luo, Liai Sun, Yingce
# Xia, Tao Qin, Sheng Zhang, Hoifung Poon and Tie-Yan Liu. BioGPT is a domain-specific generative pre-trained Transformer language model for biomedical
# text generation and mining. BioGPT follows the Transformer language model backbone, and is pre-trained on 15M PubMed abstracts from scratch.
#
# ---
#
# ## Confiuring BioGPT
#
# --
#
# This is the configuration class to store the configuration of a BioGptModel. It is used to instantiate an BioGPT model according to the specified arguments, defining the model architecture. Instantiating a configuration with the defaults will yield a similar configuration to that of the BioGPT microsoft/biogpt architecture.
#
# Configuration objects inherit from PretrainedConfig and can be used to control the model outputs. Read the documentation from PretrainedConfig for more information.
#
# Example:
#
# Copied
# ```py
# from transformers import BioGptModel, BioGptConfig
#
# # Initializing a BioGPT microsoft/biogpt style configuration
# configuration = BioGptConfig()
#
# # Initializing a model from the microsoft/biogpt style configuration
# model = BioGptModel(configuration)
#
# # Accessing the model configuration
# configuration = model.config
# ```
#
# ---
#
# ## NOTE
#
# when using a new HFT module restart kernal and do not install previous modules

# %%
# %pip install torch torchvision
from transformers import BioGptModel, BioGptConfig

# intitalise a biogpt microsoft/biogpt style config
configuration = BioGptConfig()

# initialising a model from teh microsoft/biogpt style configuration
model = BioGptModel(configuration)

# Accessing the model configuration
configuration = model.config
# Out:
# Requirement already satisfied: torch in /Users/alex/anaconda3/lib/python3.11/site-packages (2.2.1)
# Requirement already satisfied: torchvision in /Users/alex/anaconda3/lib/python3.11/site-packages (0.17.1)
# Requirement already satisfied: filelock in /Users/alex/anaconda3/lib/python3.11/site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from torch) (4.10.0)
# Requirement already satisfied: sympy in /Users/alex/anaconda3/lib/python3.11/site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /Users/alex/anaconda3/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /Users/alex/anaconda3/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /Users/alex/anaconda3/lib/python3.11/site-packages (from torch) (2023.4.0)
# Requirement already satisfied: numpy in /Users/alex/anaconda3/lib/python3.11/site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/alex/anaconda3/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# /Users/alex/anaconda3/lib/python3.11/site-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
