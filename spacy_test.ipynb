# %%
## importing spacy

# %pip install -U pip setuptools wheel
# Out:
# Requirement already satisfied: pip in /Users/alex/anaconda3/lib/python3.11/site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/8a/6a/19e9fe04fca059ccf770861c7d5721ab4c2aebc539889e97c7977528a53b/pip-24.0-py3-none-any.whl.metadata
#   Using cached pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: setuptools in /Users/alex/anaconda3/lib/python3.11/site-packages (68.0.0)
# Collecting setuptools
#   Obtaining dependency information for setuptools from https://files.pythonhosted.org/packages/c0/7a/3da654f49c95d0cc6e9549a855b5818e66a917e852ec608e77550c8dc08b/setuptools-69.1.1-py3-none-any.whl.metadata
#   Downloading setuptools-69.1.1-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: wheel in /Users/alex/anaconda3/lib/python3.11/site-packages (0.38.4)
# Collecting wheel
#   Obtaining dependency information for wheel from https://files.pythonhosted.org/packages/c7/c3/55076fc728723ef927521abaa1955213d094933dc36d4a2008d5101e1af5/wheel-0.42.0-py3-none-any.whl.metadata
#   Downloading wheel-0.42.0-py3-none-any.whl.metadata (2.2 kB)
# Using cached pip-24.0-py3-none-any.whl (2.1 MB)
# Downloading setuptools-69.1.1-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 kB 5.0 MB/s eta 0:00:0000:0100:01
# Using cached wheel-0.42.0-py3-none-any.whl (65 kB)
# Installing collected packages: wheel, setuptools, pip
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.38.4
#     Uninstalling wheel-0.38.4:
#       Successfully uninstalled wheel-0.38.4
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 68.0.0
#     Uninstalling setuptools-68.0.0:
#       Successfully uninstalled setuptools-68.0.0
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2.1
#     Uninstalling pip-23.2.1:
#       Successfully uninstalled pip-23.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.75 requires requests_mock, which is not installed.
# spyder 5.4.3 requires pyqt5<5.16, which is not installed.
# spyder 5.4.3 requires pyqtwebengine<5.16, which is not installed.
# conda-repo-cli 1.0.75 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.75 requires PyYAML==6.0.1, but you have pyyaml 6.0 which is incompatible.
# python-lsp-black 1.2.1 requires black>=22.3.0, but you have black 0.0 which is incompatible.
# Successfully installed pip-24.0 setuptools-69.1.1 wheel-0.42.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U 'spacy[apple]'
# Out:
# Collecting spacy[apple]
#   Downloading spacy-3.7.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy[apple])
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy[apple])
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy[apple])
#   Downloading murmurhash-1.0.10-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy[apple])
#   Downloading cymem-2.0.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy[apple])
#   Downloading preshed-3.0.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy[apple])
#   Downloading thinc-8.2.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy[apple])
#   Downloading wasabi-1.1.2-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy[apple])
#   Downloading srsly-2.4.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy[apple])
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy[apple])
#   Downloading weasel-0.3.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting typer<0.10.0,>=0.3.0 (from spacy[apple])
#   Downloading typer-0.9.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy[apple]) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy[apple]) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy[apple]) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy[apple]) (1.10.8)
# Requirement already satisfied: jinja2 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy[apple]) (3.1.2)
# Requirement already satisfied: setuptools in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy[apple]) (69.1.1)
# Requirement already satisfied: packaging>=20.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy[apple]) (23.1)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy[apple])
#   Downloading langcodes-3.3.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: numpy>=1.19.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy[apple]) (1.24.3)
# Collecting thinc-apple-ops<1.0.0,>=0.1.0.dev0 (from spacy[apple])
#   Downloading thinc_apple_ops-0.1.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy[apple]) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy[apple]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy[apple]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy[apple]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy[apple]) (2023.7.22)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.2.2->spacy[apple])
#   Downloading blis-0.7.11-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.2.2->spacy[apple])
#   Downloading confection-0.1.4-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy[apple]) (8.0.4)
# Collecting cloudpathlib<0.17.0,>=0.7.0 (from weasel<0.4.0,>=0.1.0->spacy[apple])
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from jinja2->spacy[apple]) (2.1.1)
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.8-cp311-cp311-macosx_11_0_arm64.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 3.2 MB/s eta 0:00:00
# Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 4.1 MB/s eta 0:00:00a 0:00:01
# Downloading murmurhash-1.0.10-cp311-cp311-macosx_11_0_arm64.whl (26 kB)
# Downloading preshed-3.0.9-cp311-cp311-macosx_11_0_arm64.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.8/128.8 kB 5.4 MB/s eta 0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp311-cp311-macosx_11_0_arm64.whl (488 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.4/488.4 kB 6.2 MB/s eta 0:00:0000:0100:01
# Downloading thinc-8.2.3-cp311-cp311-macosx_11_0_arm64.whl (781 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.1/781.1 kB 6.4 MB/s eta 0:00:0000:0100:01
# Downloading thinc_apple_ops-0.1.4-cp311-cp311-macosx_11_0_arm64.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 4.9 MB/s eta 0:00:00
# Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 3.7 MB/s eta 0:00:00
# Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Downloading weasel-0.3.4-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 3.8 MB/s eta 0:00:00
# Downloading spacy-3.7.4-cp311-cp311-macosx_11_0_arm64.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 6.5 MB/s eta 0:00:0000:0100:01
# Downloading blis-0.7.11-cp311-cp311-macosx_11_0_arm64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 8.1 MB/s eta 0:00:00a 0:00:01m
# Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 3.0 MB/s eta 0:00:00
# Downloading confection-0.1.4-py3-none-any.whl (35 kB)
# Installing collected packages: cymem, wasabi, typer, spacy-loggers, spacy-legacy, murmurhash, langcodes, cloudpathlib, catalogue, blis, srsly, preshed, confection, weasel, thinc, thinc-apple-ops, spacy
# Successfully installed blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.16.0 confection-0.1.4 cymem-2.0.8 langcodes-3.3.0 murmurhash-1.0.10 preshed-3.0.9 spacy-3.7.4 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.3 thinc-apple-ops-0.1.4 typer-0.9.0 wasabi-1.1.2 weasel-0.3.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 6.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/alex/anaconda3/lib/python3.11/site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.10.8)
# Requirement already satisfied: jinja2 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (69.1.1)
# Requirement already satisfied: packaging>=20.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/alex/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# %pip install scispacy
# Out:
# Collecting scispacy
#   Downloading scispacy-0.5.4-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from scispacy) (3.7.4)
# Collecting scipy<1.11 (from scispacy)
#   Downloading scipy-1.10.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from scispacy) (2.31.0)
# Collecting conllu (from scispacy)
#   Downloading conllu-4.5.3-py2.py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy in /Users/alex/anaconda3/lib/python3.11/site-packages (from scispacy) (1.24.3)
# Requirement already satisfied: joblib in /Users/alex/anaconda3/lib/python3.11/site-packages (from scispacy) (1.2.0)
# Collecting nmslib>=1.7.3.6 (from scispacy)
#   Downloading nmslib-2.1.1.tar.gz (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn>=0.20.3 in /Users/alex/anaconda3/lib/python3.11/site-packages (from scispacy) (1.3.0)
# Collecting pysbd (from scispacy)
#   Downloading pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting pybind11<2.6.2 (from nmslib>=1.7.3.6->scispacy)
#   Using cached pybind11-2.6.1-py2.py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: psutil in /Users/alex/anaconda3/lib/python3.11/site-packages (from nmslib>=1.7.3.6->scispacy) (5.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alex/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.20.3->scispacy) (2.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (4.65.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (1.10.8)
# Requirement already satisfied: jinja2 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.1.2)
# Requirement already satisfied: setuptools in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (69.1.1)
# Requirement already satisfied: packaging>=20.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->scispacy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->scispacy) (4.7.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/alex/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->scispacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->scispacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/alex/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->scispacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->scispacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/alex/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->scispacy) (2.1.1)
# Downloading scispacy-0.5.4-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 3.2 MB/s eta 0:00:00
# Downloading scipy-1.10.1-cp311-cp311-macosx_12_0_arm64.whl (28.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.7/28.7 MB 3.7 MB/s eta 0:00:0000:0100:01
# Downloading conllu-4.5.3-py2.py3-none-any.whl (16 kB)
# Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 4.7 MB/s eta 0:00:00
# Using cached pybind11-2.6.1-py2.py3-none-any.whl (188 kB)
# Building wheels for collected packages: nmslib
#   Building wheel for nmslib (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [172 lines of output]
#       Dependence list: ['pybind11<2.6.2', 'psutil', "numpy>=1.10.0,<1.17 ; python_version=='2.7'", "numpy>=1.10.0 ; python_version>='3.5'"]
#       /Users/alex/anaconda3/lib/python3.11/site-packages/setuptools/dist.py:472: SetuptoolsDeprecationWarning: Invalid dash-separated options
#       !!
#
#               ********************************************************************************
#               Usage of dash-separated 'description-file' will not be supported in future
#               versions. Please use the underscore name 'description_file' instead.
#
#               By 2024-Sep-26, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         opt = self.warn_dash_deprecation(opt, section)
#       /Users/alex/anaconda3/lib/python3.11/site-packages/setuptools/__init__.py:80: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#               ********************************************************************************
#
#       !!
#         dist.fetch_build_eggs(dist.setup_requires)
#       /Users/alex/anaconda3/lib/python3.11/site-packages/setuptools/dist.py:472: SetuptoolsDeprecationWarning: Invalid dash-separated options
#       !!
#
#               ********************************************************************************
#               Usage of dash-separated 'description-file' will not be supported in future
#               versions. Please use the underscore name 'description_file' instead.
#
#               By 2024-Sep-26, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         opt = self.warn_dash_deprecation(opt, section)
#       running bdist_wheel
#       running build
#       running build_ext
#       creating var
#       creating var/folders
#       creating var/folders/pc
#       creating var/folders/pc/77rl9hn521l6g12xys12l4br0000gp
#       creating var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -I/Users/alex/anaconda3/include/python3.11 -c /var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/tmpoznt0wqu.cpp -o var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/tmpoznt0wqu.o -std=c++14
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -I/Users/alex/anaconda3/include/python3.11 -c /var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/tmp0wqcrot4.cpp -o var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/tmp0wqcrot4.o -fvisibility=hidden
#       Extra compilation arguments: ['-O3', '-march=native', '-stdlib=libc++', '-mmacosx-version-min=10.7', '-DVERSION_INFO="2.1.1"', '-std=c++14', '-fvisibility=hidden']
#       building 'nmslib' extension
#       creating build
#       creating build/temp.macosx-11.1-arm64-cpython-311
#       creating build/temp.macosx-11.1-arm64-cpython-311/similarity_search
#       creating build/temp.macosx-11.1-arm64-cpython-311/similarity_search/src
#       creating build/temp.macosx-11.1-arm64-cpython-311/similarity_search/src/method
#       creating build/temp.macosx-11.1-arm64-cpython-311/similarity_search/src/space
#       creating build/temp.macosx-11.1-arm64-cpython-311/tensorflow
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -I./similarity_search/include -Itensorflow -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/Users/alex/anaconda3/lib/python3.11/site-packages/numpy/core/include -I/Users/alex/anaconda3/include/python3.11 -c ./similarity_search/src/distcomp_bregman.cc -o build/temp.macosx-11.1-arm64-cpython-311/./similarity_search/src/distcomp_bregman.o -O3 -march=native -stdlib=libc++ -mmacosx-version-min=10.7 -DVERSION_INFO=\"2.1.1\" -std=c++14 -fvisibility=hidden
#       ./similarity_search/src/distcomp_bregman.cc:83:9: warning: ./similarity_search/src/distcomp_bregman.cc(83) : WARNING: ItakuraSaitoPrecompSIMD<float>: SSE2 is not available, defaulting to pure C++ implementation! [-W#pragma-messages]
#       #pragma message WARN("ItakuraSaitoPrecompSIMD<float>: SSE2 is not available, defaulting to pure C++ implementation!")
#               ^
#       ./similarity_search/src/distcomp_bregman.cc:148:17: warning: explicit instantiation of 'ItakuraSaitoPrecompSIMD<float>' that occurs after an explicit specialization has no effect [-Winstantiation-after-specialization]
#       template float  ItakuraSaitoPrecompSIMD<float>(const float* pVect1, const float* pVect2, size_t qty);
#                       ^
#       ./similarity_search/src/distcomp_bregman.cc:80:7: note: previous template specialization is here
#       float ItakuraSaitoPrecompSIMD(const float* pVect1, const float* pVect2, size_t qty)
#             ^
#       ./similarity_search/src/distcomp_bregman.cc:217:9: warning: ./similarity_search/src/distcomp_bregman.cc(217) : WARNING: KLPrecompSIMD<float>: SSE2 is not available, defaulting to pure C++ implementation! [-W#pragma-messages]
#       #pragma message WARN("KLPrecompSIMD<float>: SSE2 is not available, defaulting to pure C++ implementation!")
#               ^
#       ./similarity_search/src/distcomp_bregman.cc:275:16: warning: explicit instantiation of 'KLPrecompSIMD<float>' that occurs after an explicit specialization has no effect [-Winstantiation-after-specialization]
#       template float KLPrecompSIMD<float>(const float* pVect1, const float* pVect2, size_t qty);
#                      ^
#       ./similarity_search/src/distcomp_bregman.cc:214:7: note: previous template specialization is here
#       float KLPrecompSIMD(const float* pVect1, const float* pVect2, size_t qty)
#             ^
#       ./similarity_search/src/distcomp_bregman.cc:329:9: warning: ./similarity_search/src/distcomp_bregman.cc(329) : WARNING: KLGeneralPrecompSIMD<float>: SSE2 is not available, defaulting to pure C++ implementation! [-W#pragma-messages]
#       #pragma message WARN("KLGeneralPrecompSIMD<float>: SSE2 is not available, defaulting to pure C++ implementation!")
#               ^
#       ./similarity_search/src/distcomp_bregman.cc:395:16: warning: explicit instantiation of 'KLGeneralPrecompSIMD<float>' that occurs after an explicit specialization has no effect [-Winstantiation-after-specialization]
#       template float KLGeneralPrecompSIMD<float>(const float* pVect1, const float* pVect2, size_t qty);
#                      ^
#       ./similarity_search/src/distcomp_bregman.cc:326:7: note: previous template specialization is here
#       float KLGeneralPrecompSIMD(const float* pVect1, const float* pVect2, size_t qty)
#             ^
#       6 warnings generated.
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -I./similarity_search/include -Itensorflow -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/Users/alex/anaconda3/lib/python3.11/site-packages/numpy/core/include -I/Users/alex/anaconda3/include/python3.11 -c ./similarity_search/src/distcomp_diverg.cc -o build/temp.macosx-11.1-arm64-cpython-311/./similarity_search/src/distcomp_diverg.o -O3 -march=native -stdlib=libc++ -mmacosx-version-min=10.7 -DVERSION_INFO=\"2.1.1\" -std=c++14 -fvisibility=hidden
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -I./similarity_search/include -Itensorflow -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/Users/alex/anaconda3/lib/python3.11/site-packages/numpy/core/include -I/Users/alex/anaconda3/include/python3.11 -c ./similarity_search/src/distcomp_edist.cc -o build/temp.macosx-11.1-arm64-cpython-311/./similarity_search/src/distcomp_edist.o -O3 -march=native -stdlib=libc++ -mmacosx-version-min=10.7 -DVERSION_INFO=\"2.1.1\" -std=c++14 -fvisibility=hidden
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -I./similarity_search/include -Itensorflow -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/Users/alex/anaconda3/lib/python3.11/site-packages/numpy/core/include -I/Users/alex/anaconda3/include/python3.11 -c ./similarity_search/src/distcomp_js.cc -o build/temp.macosx-11.1-arm64-cpython-311/./similarity_search/src/distcomp_js.o -O3 -march=native -stdlib=libc++ -mmacosx-version-min=10.7 -DVERSION_INFO=\"2.1.1\" -std=c++14 -fvisibility=hidden
#       ./similarity_search/src/distcomp_js.cc:150:9: warning: ./similarity_search/src/distcomp_js.cc(150) : WARNING: JSPrecompSIMDApproxLog<float>: SSE2 is not available, defaulting to pure C++ implementation! [-W#pragma-messages]
#       #pragma message WARN("JSPrecompSIMDApproxLog<float>: SSE2 is not available, defaulting to pure C++ implementation!")
#               ^
#       ./similarity_search/src/distcomp_js.cc:231:16: warning: explicit instantiation of 'JSPrecompSIMDApproxLog<float>' that occurs after an explicit specialization has no effect [-Winstantiation-after-specialization]
#       template float JSPrecompSIMDApproxLog<float>(const float* pVect1, const float* pVect2, size_t qty);
#                      ^
#       ./similarity_search/src/distcomp_js.cc:147:7: note: previous template specialization is here
#       float JSPrecompSIMDApproxLog(const float* pVect1, const float* pVect2, size_t qty)
#             ^
#       2 warnings generated.
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -I./similarity_search/include -Itensorflow -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/Users/alex/anaconda3/lib/python3.11/site-packages/numpy/core/include -I/Users/alex/anaconda3/include/python3.11 -c ./similarity_search/src/distcomp_l2sqr_sift.cc -o build/temp.macosx-11.1-arm64-cpython-311/./similarity_search/src/distcomp_l2sqr_sift.o -O3 -march=native -stdlib=libc++ -mmacosx-version-min=10.7 -DVERSION_INFO=\"2.1.1\" -std=c++14 -fvisibility=hidden
#       ./similarity_search/src/distcomp_l2sqr_sift.cc:55:11: warning: ./similarity_search/src/distcomp_l2sqr_sift.cc(55) : WARNING: l2SqrSIFTPrecompSSE4: SSE2 is not available [-W#pragma-messages]
#         #pragma message WARN("l2SqrSIFTPrecompSSE4: SSE2 is not available")
#                 ^
#       ./similarity_search/src/distcomp_l2sqr_sift.cc:103:9: warning: ./similarity_search/src/distcomp_l2sqr_sift.cc(103) : WARNING: l2SqrSIFTPrecompAVX: AVX2 is not available [-W#pragma-messages]
#       #pragma message WARN("l2SqrSIFTPrecompAVX: AVX2 is not available")
#               ^
#       ./similarity_search/src/distcomp_l2sqr_sift.cc:105:11: warning: ./similarity_search/src/distcomp_l2sqr_sift.cc(105) : WARNING: l2SqrSIFTPrecompAVX: SSE4 is not available [-W#pragma-messages]
#         #pragma message WARN("l2SqrSIFTPrecompAVX: SSE4 is not available")
#                 ^
#       3 warnings generated.
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -I./similarity_search/include -Itensorflow -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/Users/alex/anaconda3/lib/python3.11/site-packages/numpy/core/include -I/Users/alex/anaconda3/include/python3.11 -c ./similarity_search/src/distcomp_lp.cc -o build/temp.macosx-11.1-arm64-cpython-311/./similarity_search/src/distcomp_lp.o -O3 -march=native -stdlib=libc++ -mmacosx-version-min=10.7 -DVERSION_INFO=\"2.1.1\" -std=c++14 -fvisibility=hidden
#       ./similarity_search/src/distcomp_lp.cc:80:9: warning: ./similarity_search/src/distcomp_lp.cc(80) : WARNING: LInfNormSIMD<float>: SSE2 is not available, defaulting to pure C++ implementation! [-W#pragma-messages]
#       #pragma message WARN("LInfNormSIMD<float>: SSE2 is not available, defaulting to pure C++ implementation!")
#               ^
#       ./similarity_search/src/distcomp_lp.cc:141:16: warning: explicit instantiation of 'LInfNormSIMD<float>' that occurs after an explicit specialization has no effect [-Winstantiation-after-specialization]
#       template float LInfNormSIMD<float>(const float* pVect1, const float* pVect2, size_t qty);
#                      ^
#       ./similarity_search/src/distcomp_lp.cc:78:7: note: previous template specialization is here
#       float LInfNormSIMD(const float* pVect1, const float* pVect2, size_t qty) {
#             ^
#       ./similarity_search/src/distcomp_lp.cc:193:9: warning: ./similarity_search/src/distcomp_lp.cc(193) : WARNING: L1NormSIMD<float>: SSE2 is not available, defaulting to pure C++ implementation! [-W#pragma-messages]
#       #pragma message WARN("L1NormSIMD<float>: SSE2 is not available, defaulting to pure C++ implementation!")
#               ^
#       ./similarity_search/src/distcomp_lp.cc:253:16: warning: explicit instantiation of 'L1NormSIMD<float>' that occurs after an explicit specialization has no effect [-Winstantiation-after-specialization]
#       template float L1NormSIMD<float>(const float* pVect1, const float* pVect2, size_t qty);
#                      ^
#       ./similarity_search/src/distcomp_lp.cc:191:7: note: previous template specialization is here
#       float L1NormSIMD(const float* pVect1, const float* pVect2, size_t qty) {
#             ^
#       ./similarity_search/src/distcomp_lp.cc:306:9: warning: ./similarity_search/src/distcomp_lp.cc(306) : WARNING: L2SqrSIMD<float>: SSE2 is not available, defaulting to pure C++ implementation! [-W#pragma-messages]
#       #pragma message WARN("L2SqrSIMD<float>: SSE2 is not available, defaulting to pure C++ implementation!")
#               ^
#       ./similarity_search/src/distcomp_lp.cc:373:17: warning: explicit instantiation of 'L2NormSIMD<float>' that occurs after an explicit specialization has no effect [-Winstantiation-after-specialization]
#       template float  L2NormSIMD<float>(const float* pVect1, const float* pVect2, size_t qty);
#                       ^
#       ./similarity_search/src/distcomp_lp.cc:368:7: note: previous template specialization is here
#       float L2NormSIMD(const float* pVect1, const float* pVect2, size_t qty) {
#             ^
#       6 warnings generated.
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -I./similarity_search/include -Itensorflow -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/Users/alex/anaconda3/lib/python3.11/site-packages/numpy/core/include -I/Users/alex/anaconda3/include/python3.11 -c ./similarity_search/src/distcomp_overlap.cc -o build/temp.macosx-11.1-arm64-cpython-311/./similarity_search/src/distcomp_overlap.o -O3 -march=native -stdlib=libc++ -mmacosx-version-min=10.7 -DVERSION_INFO=\"2.1.1\" -std=c++14 -fvisibility=hidden
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -I./similarity_search/include -Itensorflow -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/Users/alex/anaconda3/lib/python3.11/site-packages/numpy/core/include -I/Users/alex/anaconda3/include/python3.11 -c ./similarity_search/src/distcomp_rankcorr.cc -o build/temp.macosx-11.1-arm64-cpython-311/./similarity_search/src/distcomp_rankcorr.o -O3 -march=native -stdlib=libc++ -mmacosx-version-min=10.7 -DVERSION_INFO=\"2.1.1\" -std=c++14 -fvisibility=hidden
#       ./similarity_search/src/distcomp_rankcorr.cc:40:9: warning: ./similarity_search/src/distcomp_rankcorr.cc(40) : WARNING: SpearmanFootruleSIMD: SSE4.2 is not available, defaulting to pure C++ implementation! [-W#pragma-messages]
#       #pragma message WARN("SpearmanFootruleSIMD: SSE4.2 is not available, defaulting to pure C++ implementation!")
#               ^
#       ./similarity_search/src/distcomp_rankcorr.cc:112:9: warning: ./similarity_search/src/distcomp_rankcorr.cc(112) : WARNING: SpearmanRhoSIMD: SSE4.2 is not available, defaulting to pure C++ implementation! [-W#pragma-messages]
#       #pragma message WARN("SpearmanRhoSIMD: SSE4.2 is not available, defaulting to pure C++ implementation!")
#               ^
#       2 warnings generated.
#       clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -fPIC -O2 -isystem /Users/alex/anaconda3/include -arch arm64 -I./similarity_search/include -Itensorflow -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/private/var/folders/pc/77rl9hn521l6g12xys12l4br0000gp/T/pip-install-zn7b35ch/nmslib_02f77dc1de564ba39e5c3f06be723d07/.eggs/pybind11-2.6.1-py3.11.egg/pybind11/include -I/Users/alex/anaconda3/lib/python3.11/site-packages/numpy/core/include -I/Users/alex/anaconda3/include/python3.11 -c ./similarity_search/src/distcomp_scalar.cc -o build/temp.macosx-11.1-arm64-cpython-311/./similarity_search/src/distcomp_scalar.o -O3 -march=native -stdlib=libc++ -mmacosx-version-min=10.7 -DVERSION_INFO=\"2.1.1\" -std=c++14 -fvisibility=hidden
#       ./similarity_search/src/distcomp_scalar.cc:85:9: error: pragma message requires parenthesized string
#       #pragma message WARN("ScalarProductSIMD<float>: SSE2 is not available, defaulting to pure C++ implementation!")
#               ^
#       ./similarity_search/src/distcomp_scalar.cc:169:18: warning: explicit instantiation of 'NormScalarProductSIMD<float>' that occurs after an explicit specialization has no effect [-Winstantiation-after-specialization]
#       template float   NormScalarProductSIMD<float>(const float* pVect1, const float* pVect2, size_t qty);
#                        ^
#       ./similarity_search/src/distcomp_scalar.cc:83:7: note: previous template specialization is here
#       float NormScalarProductSIMD(const float* pVect1, const float* pVect2, size_t qty) {
#             ^
#       ./similarity_search/src/distcomp_scalar.cc:195:9: error: pragma message requires parenthesized string
#       #pragma message WARN("ScalarProductSIMD<float>: SSE2 is not available, defaulting to pure C++ implementation!")
#               ^
#       ./similarity_search/src/distcomp_scalar.cc:246:18: warning: explicit instantiation of 'ScalarProductSIMD<float>' that occurs after an explicit specialization has no effect [-Winstantiation-after-specialization]
#       template float   ScalarProductSIMD<float>(const float* pVect1, const float* pVect2, size_t qty);
#                        ^
#       ./similarity_search/src/distcomp_scalar.cc:193:7: note: previous template specialization is here
#       float ScalarProductSIMD(const float* pVect1, const float* pVect2, size_t qty) {
#             ^
#       2 warnings and 2 errors generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for nmslib
#   Running setup.py clean for nmslib
# Failed to build nmslib
# ERROR: Could not build wheels for nmslib, which is required to install pyproject.toml-based projects
# Note: you may need to restart the kernel to use updated packages.
